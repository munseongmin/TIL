# %%
import pandas as pd
import numpy as np
import seaborn as sns

# %%
INTERNAL_PATH='./project_data/2023_alcohol_internal.xlsx'
EXTERNAL_PATH='./project_data/2023_alcohol_external.xlsx'
TOTAL_PATH='./project_data/total_alcohol.xlsx'

# %%
#총 출고량
total_alcohol=pd.read_excel(TOTAL_PATH, header=2, index_col=0, nrows=12)
total_alcohol
# Out:
#        총  출고량      탁주     약주     청주       맥주     과실주  증류식 소주  희석식 소주    위스키  \
# 연도
# 2010  3434305  412279  18841  21267  1956826   46915     785  930608  26179
# 2011  3535591  458198  18975  22329  2022215   46384     706  923028  23371
# 2012  3634218  448047  16544  23860  2103654   46505     693  950962  20428
# 2013  3628039  426216  14538  25326  2156597   52091     805  905919  18488
# 2014  3701462  430896  12320  23291  2173472   53664     861  957818  17991
# 2015  3757786  416046  11332  22249  2208808   61905    1045  955523  17402
# 2016  3709324  399673  11584  23002  2217762   56722    1307  934869  16845
# 2017  3681733  409407  10949  24849  2168596   51737    1964  948110  15989
# 2018  3641308  402596  11562  25568  2145118   56332    1769  920082  14194
# 2019  3550527  370527  11301  21874  2088837   64539    1802  917711  11911
# 2020  3304754  379992   9538  20503  1856393   80003    2001  876520   9918
# ...

# %%
import plotly.express as px
fig=px.line(total_alcohol['총  출고량'], markers=True)
fig.update_xaxes(dtick=1)
fig.update_yaxes(title_text='출고량(kl)')
fig.update_layout(showlegend=False)
fig.show()
# Out:
# <div>                            <div id="5e1d1192-63bd-40ed-a0cd-a5a480c5d8d6" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("5e1d1192-63bd-40ed-a0cd-a5a480c5d8d6")) {                    Plotly.newPlot(                        "5e1d1192-63bd-40ed-a0cd-a5a480c5d8d6",                        [{"hovertemplate":"variable=\ucd1d  \ucd9c\uace0\ub7c9<br>\uc5f0\ub3c4=%{x}<br>value=%{y}<extra></extra>","legendgroup":"\ucd1d  \ucd9c\uace0\ub7c9","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines+markers","name":"\ucd1d  \ucd9c\uace0\ub7c9","orientation":"v","showlegend":true,"x":[2010,2011,2012,2013,2014,2015,2016,2017,2018,2019,2020,2021],"xaxis":"x","y":[3434305,3535591,3634218,3628039,3701462,3757786,3709324,3681733,364130
# ...

# %%
keyword=pd.read_excel('./project_data/alcohol_keyword.xlsx', index_col=0, nrows=13)
keyword
# Out:
#         혼술    홈술  인원제한  거리두기
# date
# 2010     0     0    84    14
# 2011     0     0    43    28
# 2012     0     0    48    32
# 2013     0     0    42    28
# 2014     0     0    54    24
# 2015    54     0    50    23
# 2016  2359   118   101    44
# 2017  2238   282    49    27
# 2018  1232   244   128    34
# 2019  1030   361    44    12
# 2020  1018  1215   426  1712
# 2021   982  1462  2422   828
# 2022   729   847   787   793

# %%
import plotly.express as px

fig=px.bar(keyword, barmode="group")
fig.update_xaxes(title_text='연도', dtick=1)
fig.update_yaxes(title_text='키워드 포함 기사 개수')
fig.update_layout(legend_title='키워드')
fig.show()
# Out:
# <div>                            <div id="5e4d7419-3c91-4235-9ae0-00897f7e9385" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("5e4d7419-3c91-4235-9ae0-00897f7e9385")) {                    Plotly.newPlot(                        "5e4d7419-3c91-4235-9ae0-00897f7e9385",                        [{"alignmentgroup":"True","hovertemplate":"variable=\ud63c\uc220<br>date=%{x}<br>value=%{y}<extra></extra>","legendgroup":"\ud63c\uc220","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"\ud63c\uc220","offsetgroup":"\ud63c\uc220","orientation":"v","showlegend":true,"textposition":"auto","x":[2010,2011,2012,2013,2014,2015,2016,2017,2018,2019,2020,2021,2022],"xaxis":"x","y":[0,0,0,0,0,54,2359,2238,1232,1030,1018,982,729],"yaxis":"y","type":"bar"},{"alignme
# ...

# %%
keyword2=pd.read_excel('./project_data/alcohol_keyword2.xlsx', index_col=0, nrows=13)
keyword2
# Out:
#       순하리  편의점 맥주(4캔 만 원)
# date
# 2010    0             170
# 2011    0             171
# 2012    0             249
# 2013    0             216
# 2014    0             274
# 2015  842             310
# 2016  251             434
# 2017   55             647
# 2018   68             756
# 2019   67             961
# 2020    9             725
# 2021   39             825
# 2022   42             808

# %%
import plotly.express as px

fig=px.bar(keyword2, barmode="group")
fig.update_layout(title_text='키워드 사용 시기')
fig.update_xaxes(title_text='연도', dtick=1)
fig.update_yaxes(title_text='키워드 포함 기사 개수')
fig.update_layout(legend_title='키워드')
fig.show()
# Out:
# <div>                            <div id="9aa0944a-f39c-4afe-8e7b-2f6432180298" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("9aa0944a-f39c-4afe-8e7b-2f6432180298")) {                    Plotly.newPlot(                        "9aa0944a-f39c-4afe-8e7b-2f6432180298",                        [{"alignmentgroup":"True","hovertemplate":"variable=\uc21c\ud558\ub9ac<br>date=%{x}<br>value=%{y}<extra></extra>","legendgroup":"\uc21c\ud558\ub9ac","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"\uc21c\ud558\ub9ac","offsetgroup":"\uc21c\ud558\ub9ac","orientation":"v","showlegend":true,"textposition":"auto","x":[2010,2011,2012,2013,2014,2015,2016,2017,2018,2019,2020,2021,2022],"xaxis":"x","y":[0,0,0,0,0,842,251,55,68,67,9,39,42],"yaxis":"y","type":"ba
# ...

# %%
keyword3=pd.read_excel('./project_data/alcohol_keyword3.xlsx', index_col=0, nrows=13)
keyword3
# Out:
#       맥주 가격 인상  주류 가격 인상  소주 가격 인상  주정 가격 인상
# date
# 2010       158       167       204        23
# 2011       423       402       217        21
# 2012       594       388       437       149
# 2013       217       299       435        47
# 2014       178       183       123        13
# 2015       337       554       586        28
# 2016       715       430       592        11
# 2017       491       356       287         9
# 2018       280       291       210        17
# 2019       768       636       724        36
# 2020        99       179       103        15
# 2021       175       360       105         4
# 2022       663       763       583       164

# %%
import plotly.express as px

fig=px.bar(keyword3, barmode="group")
fig.update_layout(title_text='키워드 사용 시기')
fig.update_xaxes(title_text='연도', dtick=1)
fig.update_yaxes(title_text='키워드 포함 기사 개수')
fig.update_layout(legend_title='키워드')
fig.show()
# Out:
# <div>                            <div id="2e847f3d-be22-420e-b72e-d173112bc4e6" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("2e847f3d-be22-420e-b72e-d173112bc4e6")) {                    Plotly.newPlot(                        "2e847f3d-be22-420e-b72e-d173112bc4e6",                        [{"alignmentgroup":"True","hovertemplate":"variable=\ub9e5\uc8fc \uac00\uaca9 \uc778\uc0c1<br>date=%{x}<br>value=%{y}<extra></extra>","legendgroup":"\ub9e5\uc8fc \uac00\uaca9 \uc778\uc0c1","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"\ub9e5\uc8fc \uac00\uaca9 \uc778\uc0c1","offsetgroup":"\ub9e5\uc8fc \uac00\uaca9 \uc778\uc0c1","orientation":"v","showlegend":true,"textposition":"auto","x":[2010,2011,2012,2013,2014,2015,2016,2017,2018,2019,2020,2021,2
# ...

# %%
keyword4=pd.read_excel('./project_data/alcohol_keyword4.xlsx', index_col=0, nrows=13)
keyword4
# Out:
#       수입 맥주,  편의점 맥주 AND  (4캔 OR  4 캔 OR  만원 OR  만 원)
# date
# 2010                                              170
# 2011                                              171
# 2012                                              249
# 2013                                              216
# 2014                                              274
# 2015                                              310
# 2016                                              434
# 2017                                              647
# 2018                                              756
# 2019                                              961
# 2020                                              725
# 2021                                              825
# 2022                                              808

# %%
import plotly.express as px

fig=px.bar(keyword4, barmode="group")
fig.update_layout(title_text='키워드 사용 시기')
fig.update_xaxes(title_text='연도', dtick=1)
fig.update_yaxes(title_text='키워드 포함 기사 개수')
fig.update_layout(legend_title='키워드')
fig.show()
# Out:
# <div>                            <div id="fbae0281-748c-4bc4-a75e-533702b3970c" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("fbae0281-748c-4bc4-a75e-533702b3970c")) {                    Plotly.newPlot(                        "fbae0281-748c-4bc4-a75e-533702b3970c",                        [{"alignmentgroup":"True","hovertemplate":"variable=\uc218\uc785 \ub9e5\uc8fc,  \ud3b8\uc758\uc810 \ub9e5\uc8fc AND  (4\uce94 OR  4 \uce94 OR  \ub9cc\uc6d0 OR  \ub9cc \uc6d0)<br>date=%{x}<br>value=%{y}<extra></extra>","legendgroup":"\uc218\uc785 \ub9e5\uc8fc,  \ud3b8\uc758\uc810 \ub9e5\uc8fc AND  (4\uce94 OR  4 \uce94 OR  \ub9cc\uc6d0 OR  \ub9cc \uc6d0)","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"\uc218\uc785 \ub9e5\uc8fc,  \ud3b8\uc758\uc810 \ub9
# ...

# %%
from plotly.subplots import make_subplots
import plotly.graph_objects as go

fig = make_subplots(specs=[[{"secondary_y": True}]])

fig.add_trace(go.Scatter(x=total_alcohol.index, y=total_alcohol['총  출고량'], name='총 출고량', line=dict(color='blue')),
    secondary_y=True)

fig.add_trace(go.Bar(x=keyword.index, y=keyword.혼술, name='혼술', marker=dict(color='#0D8ECF'), opacity=0.5),
    secondary_y=False)

fig.add_trace(go.Bar(x=keyword.index, y=keyword.홈술, name='홈술', marker=dict(color='#B0DE09'), opacity=0.5),
    secondary_y=False)

fig.update_xaxes(title_text='연도', dtick=1)
fig.update_yaxes(title_text='총 출고량', secondary_y=True)
fig.update_yaxes(title_text='키워드 포함 기사 개수', secondary_y=False)

fig.show()
# Out:
# <div>                            <div id="00f872a6-9392-4a09-88a5-5105211140d9" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("00f872a6-9392-4a09-88a5-5105211140d9")) {                    Plotly.newPlot(                        "00f872a6-9392-4a09-88a5-5105211140d9",                        [{"line":{"color":"blue"},"name":"\ucd1d \ucd9c\uace0\ub7c9","x":[2010,2011,2012,2013,2014,2015,2016,2017,2018,2019,2020,2021],"y":[3434305,3535591,3634218,3628039,3701462,3757786,3709324,3681733,3641308,3550527,3304754,3230916],"type":"scatter","xaxis":"x","yaxis":"y2"},{"marker":{"color":"#0D8ECF"},"name":"\ud63c\uc220","opacity":0.5,"x":[2010,2011,2012,2013,2014,2015,2016,2017,2018,2019,2020,2021,2022],"y":[0,0,0,0,0,54,2359,2238,1232,1030,1018,982,729],"type":
# ...

# %%
#주류별 출고량
total_alcohol.drop(['총  출고량', '기타 주류'], axis=1)
# Out:
#           탁주     약주     청주       맥주     과실주  증류식 소주  희석식 소주    위스키   브랜디  \
# 연도
# 2010  412279  18841  21267  1956826   46915     785  930608  26179  1113
# 2011  458198  18975  22329  2022215   46384     706  923028  23371   927
# 2012  448047  16544  23860  2103654   46505     693  950962  20428   704
# 2013  426216  14538  25326  2156597   52091     805  905919  18488   744
# 2014  430896  12320  23291  2173472   53664     861  957818  17991   998
# 2015  416046  11332  22249  2208808   61905    1045  955523  17402   642
# 2016  399673  11584  23002  2217762   56722    1307  934869  16845   737
# 2017  409407  10949  24849  2168596   51737    1964  948110  15989   607
# 2018  402596  11562  25568  2145118   56332    1769  920082  14194   558
# 2019  370527  11301  21874  2088837   64539    1802  917711  11911   543
# 2020  379992   9538  20503  1856393   80003    2001  876520   9918   570
# 2021  363135  11370  21341  1807620  113762    2567  827627  10720   648
#
# ...

# %%
data=pd.DataFrame(total_alcohol.drop(['총  출고량', '기타 주류'], axis=1).loc[2021])
data=data.reset_index()
data
# Out:
#      index     2021
# 0       탁주   363135
# 1       약주    11370
# 2       청주    21341
# 3       맥주  1807620
# 4      과실주   113762
# 5   증류식 소주     2567
# 6   희석식 소주   827627
# 7      위스키    10720
# 8      브랜디      648
# 9   일반 증류주    12509
# 10     리큐르     8291

# %%
import matplotlib.pyplot as plt

ratio = [34, 32, 16, 18]
labels = ['Apple', 'Banana', 'Melon', 'Grapes']
explode = [0.05, 0.05, 0.05, 0.05]
colors = ['yellow', 'green'] 'whitesmoke', 'lightgray']

plt.pie(ratio, labels=labels, autopct='%.1f%%', startangle=260, counterclock=False, explode=explode, shadow=True, colors=colors)
plt.show()

# %%
import plotly.express as px

fig=px.pie(data, values=2021, names='index')
fig.update_traces(textfont_size=20, textfont_color='white', textposition='inside', textinfo='percent+label')
fig.update_layout(legend_title='주류별')
fig.update_traces(hole=.3)
                  
fig.show()
# Out:
# <div>                            <div id="b34dd8e6-681c-4e34-9e16-4254aad60a60" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("b34dd8e6-681c-4e34-9e16-4254aad60a60")) {                    Plotly.newPlot(                        "b34dd8e6-681c-4e34-9e16-4254aad60a60",                        [{"domain":{"x":[0.0,1.0],"y":[0.0,1.0]},"hovertemplate":"index=%{label}<br>2021=%{value}<extra></extra>","labels":["\ud0c1\uc8fc","\uc57d\uc8fc","\uccad\uc8fc","\ub9e5\uc8fc","\uacfc\uc2e4\uc8fc","\uc99d\ub958\uc2dd \uc18c\uc8fc","\ud76c\uc11d\uc2dd \uc18c\uc8fc","\uc704\uc2a4\ud0a4","\ube0c\ub79c\ub514","\uc77c\ubc18 \uc99d\ub958\uc8fc","\ub9ac\ud050\ub974"],"legendgroup":"","name":"","showlegend":true,"values":[363135,11370,21341,1807620,113762,2567,827627,1072
# ...

# %%
import plotly.express as px
fig=px.line(total_alcohol.drop(['총  출고량', '기타 주류'], axis=1), markers=True)
#fig.update_layout(title_text='주류별 출고량')
fig.update_xaxes(dtick=1)
fig.update_yaxes(title_text='출고량(kl)')
fig.update_layout(legend_title_text='주류별')

fig.add_annotation(x=2021, y=1807620,
            text="맥주",
            showarrow=False,
            font_size=15,
            xanchor = 'left')

fig.add_annotation(x=2021, y=827627,
            text="소주",
            showarrow=False,
            font_size=15,
            xanchor = 'left')

fig.add_annotation(x=2021, y=363135,
            text="막걸리",
            showarrow=False,
            font_size=15,
            xanchor = 'left')

fig.show()
# Out:
# <div>                            <div id="2492ded1-84c9-4453-b3fa-3d89e7a0d35f" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("2492ded1-84c9-4453-b3fa-3d89e7a0d35f")) {                    Plotly.newPlot(                        "2492ded1-84c9-4453-b3fa-3d89e7a0d35f",                        [{"hovertemplate":"variable=\ud0c1\uc8fc<br>\uc5f0\ub3c4=%{x}<br>value=%{y}<extra></extra>","legendgroup":"\ud0c1\uc8fc","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines+markers","name":"\ud0c1\uc8fc","orientation":"v","showlegend":true,"x":[2010,2011,2012,2013,2014,2015,2016,2017,2018,2019,2020,2021],"xaxis":"x","y":[412279,458198,448047,426216,430896,416046,399673,409407,402596,370527,379992,363135],"yaxis":"y","type":"scatter
# ...

# %%
#소주, 맥주, 막걸리 제외
total_alcohol.drop(['총  출고량', '탁주', '맥주', '희석식 소주', '기타 주류'], axis=1)
# Out:
#          약주     청주     과실주  증류식 소주    위스키   브랜디  일반 증류주    리큐르
# 연도
# 2010  18841  21267   46915     785  26179  1113    9390   4779
# 2011  18975  22329   46384     706  23371   927   10525   4621
# 2012  16544  23860   46505     693  20428   704   11790   6547
# 2013  14538  25326   52091     805  18488   744   15214   6806
# 2014  12320  23291   53664     861  17991   998   16832   6844
# 2015  11332  22249   61905    1045  17402   642   19226  36316
# 2016  11584  23002   56722    1307  16845   737   15460  18856
# 2017  10949  24849   51737    1964  15989   607   14409  10246
# 2018  11562  25568   56332    1769  14194   558   14162   9711
# 2019  11301  21874   64539    1802  11911   543   13673   9020
# 2020   9538  20503   80003    2001   9918   570   12902   7224
# 2021  11370  21341  113762    2567  10720   648   12509   8291

# %%
import plotly.express as px
fig=px.line(total_alcohol.drop(['총  출고량', '탁주', '맥주', '희석식 소주', '기타 주류'], axis=1), markers=True)
#fig_i.update_layout(title_text='소주, 맥주, 막걸리 제외 주류별 출고량')
fig.update_xaxes(dtick=1)
fig.update_yaxes(title_text='출고량(kl)')
fig.update_layout(legend_title_text='주류별')

fig.add_annotation(x=2021, y=113762,
            text="과실주",
            showarrow=False,
            font_size=15,
            xanchor = 'left')

fig.show()
#과실주 증가 이유
#2015년 리큐르의 증가 이유 : 처음처럼 순하리 출시
# Out:
# <div>                            <div id="188207a1-d36c-4dfc-9729-b84465ef8172" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("188207a1-d36c-4dfc-9729-b84465ef8172")) {                    Plotly.newPlot(                        "188207a1-d36c-4dfc-9729-b84465ef8172",                        [{"hovertemplate":"variable=\uc57d\uc8fc<br>\uc5f0\ub3c4=%{x}<br>value=%{y}<extra></extra>","legendgroup":"\uc57d\uc8fc","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines+markers","name":"\uc57d\uc8fc","orientation":"v","showlegend":true,"x":[2010,2011,2012,2013,2014,2015,2016,2017,2018,2019,2020,2021],"xaxis":"x","y":[18841,18975,16544,14538,12320,11332,11584,10949,11562,11301,9538,11370],"yaxis":"y","type":"scatter"},{"hovertem
# ...

# %%
#주요 주류 출고량(국내분)
alcohol_internal=pd.read_excel(INTERNAL_PATH, header=3, index_col='연도', nrows=12)
alcohol_internal
# Out:
#         총 출고량      탁주     약주     청주       맥주    과실주  증류식 소주  희석식 소주   위스키  \
# 연도
# 2010  3321975  412269  18841  18394  1909923  21519     717  930605  3417
# 2011  3411799  458198  18975  19301  1963170  19866     609  923024  1954
# 2012  3490857  448046  16544  18969  2031271  16350     585  950884  1196
# 2013  3454922  426216  14538  18998  2062054  17881     658  905903   940
# 2014  3505090  430896  12320  19466  2055761  17617     755  957656   907
# 2015  3498604  416046  11332  18459  2040833  15737     954  955507   439
# 2016  3383108  399667  11490  18753  1978699  16721    1203  932258   470
# 2017  3248262  409407  10820  18312  1823899  13193    1857  945860   205
# 2018  3135485  402580  11479  19068  1736927  12054    1651  917959   126
# 2019  3077195  370500  11213  17784  1715995  10926    1714  915596    72
# 2020  2900821  379976   9483  17113  1566914  11315    1929  874537    56
# 2021  2813839  363132  11317  18217  1538968  17485    2480  825848    74
#
# ...

# %%
alcohol_internal['총 출고량']
# Out:
# 연도
# 2010    3321975
# 2011    3411799
# 2012    3490857
# 2013    3454922
# 2014    3505090
# 2015    3498604
# 2016    3383108
# 2017    3248262
# 2018    3135485
# 2019    3077195
# 2020    2900821
# 2021    2813839
# Name: 총 출고량, dtype: int64

# %%
import plotly.express as px
fig_i=px.line(alcohol_internal['총 출고량'], markers=True)
fig_i.update_layout(title_text='총 출고량(국내 주류)')
fig_i.update_xaxes(dtick=1)
fig_i.update_yaxes(title_text='출고량(kl)')
fig_i.update_layout(showlegend=False)
fig_i.show()
#15년 이후로 하락세 이유 : 혼술, 회식거부
# Out:
# <div>                            <div id="8cf4c9a9-8359-49b9-a0f6-0b4f290f887b" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("8cf4c9a9-8359-49b9-a0f6-0b4f290f887b")) {                    Plotly.newPlot(                        "8cf4c9a9-8359-49b9-a0f6-0b4f290f887b",                        [{"hovertemplate":"variable=\ucd1d \ucd9c\uace0\ub7c9<br>\uc5f0\ub3c4=%{x}<br>value=%{y}<extra></extra>","legendgroup":"\ucd1d \ucd9c\uace0\ub7c9","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines+markers","name":"\ucd1d \ucd9c\uace0\ub7c9","orientation":"v","showlegend":true,"x":[2010,2011,2012,2013,2014,2015,2016,2017,2018,2019,2020,2021],"xaxis":"x","y":[3321975,3411799,3490857,3454922,3505090,3498604,3383108,3248262,3135485,3
# ...

# %%
alcohol_internal=alcohol_internal.drop(['총 출고량', '기타 주류'], axis=1)
alcohol_internal
# Out:
#           탁주     약주     청주       맥주    과실주  증류식 소주  희석식 소주   위스키  브랜디  일반 증류주  \
# 연도
# 2010  412269  18841  18394  1909923  21519     717  930605  3417   66    3708
# 2011  458198  18975  19301  1963170  19866     609  923024  1954   75    3925
# 2012  448046  16544  18969  2031271  16350     585  950884  1196   73    3999
# 2013  426216  14538  18998  2062054  17881     658  905903   940   75    4787
# 2014  430896  12320  19466  2055761  17617     755  957656   907   67    6068
# 2015  416046  11332  18459  2040833  15737     954  955507   439   71    5449
# 2016  399667  11490  18753  1978699  16721    1203  932258   470   84    3903
# 2017  409407  10820  18312  1823899  13193    1857  945860   205   77    3861
# 2018  402580  11479  19068  1736927  12054    1651  917959   126    1    1740
# 2019  370500  11213  17784  1715995  10926    1714  915596    72   -2    1683
# 2020  379976   9483  17113  1566914  11315    1929  874537    56   -1    1559
# ...

# %%
from plotly.subplots import make_subplots
import plotly.graph_objects as go

fig = make_subplots(specs=[[{"secondary_y": True}]])

# fig.add_trace(go.Scatter(x=alcohol_internal.index, y=alcohol_internal.맥주, name='국산 맥주 출고량', line=dict(color='purple')),
#     secondary_y=True)

fig.add_trace(go.Scatter(x=alcohol_external.index, y=alcohol_external.맥주, name='수입 맥주 출고량', line=dict(color='blue')),
    secondary_y=True)

fig.add_trace(go.Bar(x=keyword2.index, y=keyword2['편의점 맥주(4캔 만 원)'], name='편의점 맥주', marker=dict(color='#0D8ECF'), opacity=0.5),
    secondary_y=False)

fig.update_xaxes(title_text='연도', dtick=1)
fig.update_yaxes(title_text='총 출고량', secondary_y=True)
fig.update_yaxes(title_text='키워드 포함 기사 개수', secondary_y=False)

fig.show()
# Out:
# <div>                            <div id="7a0fc5d0-2e24-4901-8904-c1db3d640838" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("7a0fc5d0-2e24-4901-8904-c1db3d640838")) {                    Plotly.newPlot(                        "7a0fc5d0-2e24-4901-8904-c1db3d640838",                        [{"line":{"color":"blue"},"name":"\uc218\uc785 \ub9e5\uc8fc \ucd9c\uace0\ub7c9","x":[2010,2011,2012,2013,2014,2015,2016,2017,2018,2019,2020,2021,2022],"y":[48713,58993,74750,95211,119501,170919,220508,331211,387981,360132,277927,257932,228747],"type":"scatter","xaxis":"x","yaxis":"y2"},{"marker":{"color":"#0D8ECF"},"name":"\ud3b8\uc758\uc810 \ub9e5\uc8fc","opacity":0.5,"x":[2010,2011,2012,2013,2014,2015,2016,2017,2018,2019,2020,2021,2022],"y":[170,171,249,216,274,
# ...

# %%
import plotly.express as px
fig=px.line(alcohol_internal, markers=True)
fig.update_xaxes(dtick=1)
fig.update_yaxes(title_text='출고량(kl)')
fig.update_layout(legend_title_text='주류별')

fig.add_annotation(x=2021, y=1538968,
            text="맥주",
            showarrow=False,
            font_size=15,
            xanchor = 'left')
fig.add_annotation(x=2021, y=825848,
            text="소주",
            showarrow=False,
            font_size=15,
            xanchor = 'left')
fig.add_annotation(x=2021, y=363132,
            text="막걸리",
            showarrow=False,
            font_size=15,
            xanchor = 'left')

fig.show()
# Out:
# <div>                            <div id="b5ff3792-3bef-4199-911d-b72c83b41911" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("b5ff3792-3bef-4199-911d-b72c83b41911")) {                    Plotly.newPlot(                        "b5ff3792-3bef-4199-911d-b72c83b41911",                        [{"hovertemplate":"variable=\ud0c1\uc8fc<br>\uc5f0\ub3c4=%{x}<br>value=%{y}<extra></extra>","legendgroup":"\ud0c1\uc8fc","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines+markers","name":"\ud0c1\uc8fc","orientation":"v","showlegend":true,"x":[2010,2011,2012,2013,2014,2015,2016,2017,2018,2019,2020,2021],"xaxis":"x","y":[412269,458198,448046,426216,430896,416046,399667,409407,402580,370500,379976,363132],"yaxis":"y","type":"scatter
# ...

# %%
alcohol_internal.drop(['탁주', '맥주', '희석식 소주'], axis=1)
# Out:
#          약주     청주    과실주  증류식 소주   위스키  브랜디  일반 증류주    리큐르
# 연도
# 2010  18841  18394  21519     717  3417   66    3708    426
# 2011  18975  19301  19866     609  1954   75    3925    306
# 2012  16544  18969  16350     585  1196   73    3999    297
# 2013  14538  18998  17881     658   940   75    4787    278
# 2014  12320  19466  17617     755   907   67    6068    284
# 2015  11332  18459  15737     954   439   71    5449  29856
# 2016  11490  18753  16721    1203   470   84    3903  13720
# 2017  10820  18312  13193    1857   205   77    3861   5604
# 2018  11479  19068  12054    1651   126    1    1740   3255
# 2019  11213  17784  10926    1714    72   -2    1683   2536
# 2020   9483  17113  11315    1929    56   -1    1559   1989
# 2021  11317  18217  17485    2480    74    0    1585   3238

# %%
import plotly.express as px
fig=px.line(alcohol_internal.drop(['탁주', '맥주', '희석식 소주'], axis=1), markers=True)
#fig.update_layout(title_text='소주, 맥주, 막걸리 제외 주류별 출고량(국내 주류)')
fig.update_xaxes(dtick=1)
fig.update_yaxes(title_text='출고량(kl)')
fig.update_layout(legend_title_text='주류별')

fig.show()
# Out:
# <div>                            <div id="b450eacf-cef5-448e-98c9-b6a35dd803d0" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("b450eacf-cef5-448e-98c9-b6a35dd803d0")) {                    Plotly.newPlot(                        "b450eacf-cef5-448e-98c9-b6a35dd803d0",                        [{"hovertemplate":"variable=\uc57d\uc8fc<br>\uc5f0\ub3c4=%{x}<br>value=%{y}<extra></extra>","legendgroup":"\uc57d\uc8fc","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines+markers","name":"\uc57d\uc8fc","orientation":"v","showlegend":true,"x":[2010,2011,2012,2013,2014,2015,2016,2017,2018,2019,2020,2021],"xaxis":"x","y":[18841,18975,16544,14538,12320,11332,11490,10820,11479,11213,9483,11317],"yaxis":"y","type":"scatter"},{"hovertem
# ...

# %%
from plotly.subplots import make_subplots
import plotly.graph_objects as go

fig = make_subplots(specs=[[{"secondary_y": True}]])

fig.add_trace(go.Scatter(x=alcohol_internal.index, y=alcohol_internal.리큐르, name='리큐르', line=dict(color='yellowgreen')),
    secondary_y=True)

fig.add_trace(go.Bar(x=keyword2.index, y=keyword2.순하리, name='순하리', marker=dict(color='#0D8ECF'), opacity=0.5),
    secondary_y=False)

fig.update_xaxes(title_text='연도', dtick=1)
fig.update_yaxes(title_text='총 출고량', secondary_y=True)
fig.update_yaxes(title_text='키워드 포함 기사 개수', secondary_y=False)

fig.show()
# Out:
# <div>                            <div id="f17d5474-e8fa-4afa-acd5-eb9edae9c685" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("f17d5474-e8fa-4afa-acd5-eb9edae9c685")) {                    Plotly.newPlot(                        "f17d5474-e8fa-4afa-acd5-eb9edae9c685",                        [{"line":{"color":"yellowgreen"},"name":"\ub9ac\ud050\ub974","x":[2010,2011,2012,2013,2014,2015,2016,2017,2018,2019,2020,2021],"y":[426,306,297,278,284,29856,13720,5604,3255,2536,1989,3238],"type":"scatter","xaxis":"x","yaxis":"y2"},{"marker":{"color":"#0D8ECF"},"name":"\uc21c\ud558\ub9ac","opacity":0.5,"x":[2010,2011,2012,2013,2014,2015,2016,2017,2018,2019,2020,2021,2022],"y":[0,0,0,0,0,842,251,55,68,67,9,39,42],"type":"bar","xaxis":"x","yaxis":"y"}],            
# ...

# %%
import plotly.express as px
fig=px.line(alcohol_internal.drop(['탁주', '맥주', '희석식 소주'], axis=1), markers=True)
#fig.update_layout(title_text='소주, 맥주, 막걸리 제외 주류별 출고량(국내 주류)')
fig.update_xaxes(dtick=1)
fig.update_yaxes(title_text='출고량(kl)')
fig.update_layout(legend_title_text='주류별')

fig.add_annotation(x=2021, y=17485,
            text="과실주 54.53% 증가",
            showarrow=True,
            arrowhead=1,
            font_size=15)
fig.add_annotation(x=2021, y=2480,
            text="증류식 소주 28.56% 증가",
            showarrow=True,
            arrowhead=1,
            font_size=15)
fig.add_annotation(x=2015, y=29856,
            text="증류식 소주 28.56% 증가",
            showarrow=True,
            arrowhead=1,
            font_size=15)

fig.show()
#20년 이후로 과실주, 약주, 증류식 소주 등 전통주 소비 증가
# Out:
# <div>                            <div id="b76f4587-753d-4398-b994-027749edda38" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("b76f4587-753d-4398-b994-027749edda38")) {                    Plotly.newPlot(                        "b76f4587-753d-4398-b994-027749edda38",                        [{"hovertemplate":"variable=\uc57d\uc8fc<br>\uc5f0\ub3c4=%{x}<br>value=%{y}<extra></extra>","legendgroup":"\uc57d\uc8fc","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines+markers","name":"\uc57d\uc8fc","orientation":"v","showlegend":true,"x":[2010,2011,2012,2013,2014,2015,2016,2017,2018,2019,2020,2021],"xaxis":"x","y":[18841,18975,16544,14538,12320,11332,11490,10820,11479,11213,9483,11317],"yaxis":"y","type":"scatter"},{"hovertem
# ...

# %%
fruit=alcohol_internal['과실주'].tail(2).pct_change()*100
fruit=fruit.dropna()
fruit=pd.DataFrame(fruit).rename(index={2021 : 2020.5})

# %%
drug=alcohol_internal['약주'].tail(2).pct_change()*100
drug=drug.dropna()
drug=pd.DataFrame(drug).rename(index={2021 : 2020.5})

# %%
soju=alcohol_internal['증류식 소주'].tail(2).pct_change()*100
soju=soju.dropna()
soju=pd.DataFrame(soju).rename(index={2021 : 2020.5})

# %%
soonhali=alcohol_internal['리큐르'].pct_change()*100
soonhali
# Out:
# 연도
# 2010             NaN
# 2011      -28.169014
# 2012       -2.941176
# 2013       -6.397306
# 2014        2.158273
# 2015    10412.676056
# 2016      -54.046088
# 2017      -59.154519
# 2018      -41.916488
# 2019      -22.089094
# 2020      -21.569401
# 2021       62.795375
# Name: 리큐르, dtype: float64

# %%
td=[fruit, drug, soju]
tradition=pd.concat(td, axis=1)
tradition=tradition.T
tradition
# Out:
# 연도         2020.5
# 과실주     54.529386
# 약주      19.339871
# 증류식 소주  28.564023

# %%
import plotly.express as px
fig_i=px.line(alcohol_internal['리큐르'], markers=True)
fig_i.update_layout(title_text='리큐르 출고량')
fig_i.update_xaxes(dtick=1)
fig_i.update_yaxes(title_text='출고량(kl)')
fig_i.update_layout(showlegend=False)
fig_i.show()
# Out:
# <div>                            <div id="fd22fa36-c585-4d08-8f7d-9c7a6d5a1cc6" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("fd22fa36-c585-4d08-8f7d-9c7a6d5a1cc6")) {                    Plotly.newPlot(                        "fd22fa36-c585-4d08-8f7d-9c7a6d5a1cc6",                        [{"hovertemplate":"variable=\ub9ac\ud050\ub974<br>\uc5f0\ub3c4=%{x}<br>value=%{y}<extra></extra>","legendgroup":"\ub9ac\ud050\ub974","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines+markers","name":"\ub9ac\ud050\ub974","orientation":"v","showlegend":true,"x":[2010,2011,2012,2013,2014,2015,2016,2017,2018,2019,2020,2021],"xaxis":"x","y":[426,306,297,278,284,29856,13720,5604,3255,2536,1989,3238],"yaxis":"y","type":"scatter"}],     
# ...

# %%
#주요 주류 출고량(수입분)
alcohol_external=pd.read_excel(EXTERNAL_PATH, header=2, index_col=0, nrows=20)

# %%
alcohol_external=alcohol_external.drop(['HS 품목번호'], axis=1)

# %%
alcohol_external=alcohol_external.T
alcohol_external
# Out:
# 주류별       맥주  포도주 (원액포함)  포도주 (베르뭇 등\n기타유사포도주)  과실발효주 (사과술등)    청주  약주  \
# 2010   48713       24568                   337           561  3425   0
# 2011   58993       26004                   141           486  3555   0
# 2012   74750       28084                   287           807  3781   4
# 2013   95211       32557                   435          1194  4367   8
# 2014  119501       33100                  1344          1179  4094   0
# 2015  170919       36815                  1146          1480  4053   0
# 2016  220508       37384                  1017           871  4497   0
# 2017  331211       36144                  1387           369  5400   0
# 2018  387981       40292                  1444          3083  6308   0
# 2019  360132       43495                  1488          6581  4111   0
# 2020  277927       54127                  1655         11429  2379   0
# 2021  257932       76575                  1827         14710  3109   0
# ...

# %%
alcohol_external.sum(axis=1)
# Out:
# 2010    113471
# 2011    125410
# 2012    145325
# 2013    173610
# 2014    200966
# 2015    257004
# 2016    309825
# 2017    421637
# 2018    489476
# 2019    464527
# 2020    393890
# 2021    408688
# 2022    385456
# dtype: int64

# %%
alcohol_external['총 출고량']=alcohol_external.sum(axis=1)
alcohol_external
# Out:
# 주류별       맥주  포도주 (원액포함)  포도주 (베르뭇 등\n기타유사포도주)  과실발효주 (사과술등)    청주  약주  \
# 2010   48713       24568                   337           561  3425   0
# 2011   58993       26004                   141           486  3555   0
# 2012   74750       28084                   287           807  3781   4
# 2013   95211       32557                   435          1194  4367   8
# 2014  119501       33100                  1344          1179  4094   0
# 2015  170919       36815                  1146          1480  4053   0
# 2016  220508       37384                  1017           871  4497   0
# 2017  331211       36144                  1387           369  5400   0
# 2018  387981       40292                  1444          3083  6308   0
# 2019  360132       43495                  1488          6581  4111   0
# 2020  277927       54127                  1655         11429  2379   0
# 2021  257932       76575                  1827         14710  3109   0
# ...

# %%
import plotly.express as px
fig=px.line(alcohol_external['총 출고량'], markers=True)
fig.update_layout(title_text='총 출고량(수입 주류)')
fig.update_xaxes(title_text='연도', dtick=1)
fig.update_yaxes(title_text='출고량(kl)')
fig.update_layout(showlegend=False)
fig.show()
# Out:
# <div>                            <div id="b427cf40-47f2-4a4f-882a-961156e2070a" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("b427cf40-47f2-4a4f-882a-961156e2070a")) {                    Plotly.newPlot(                        "b427cf40-47f2-4a4f-882a-961156e2070a",                        [{"hovertemplate":"variable=\ucd1d \ucd9c\uace0\ub7c9<br>index=%{x}<br>value=%{y}<extra></extra>","legendgroup":"\ucd1d \ucd9c\uace0\ub7c9","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines+markers","name":"\ucd1d \ucd9c\uace0\ub7c9","orientation":"v","showlegend":true,"x":[2010,2011,2012,2013,2014,2015,2016,2017,2018,2019,2020,2021,2022],"xaxis":"x","y":[113471,125410,145325,173610,200966,257004,309825,421637,489476,464527,39389
# ...

# %%
import plotly.express as px
fig=px.line(alcohol_external.drop(['총 출고량'], axis=1), markers=True)
#fig.update_layout(title_text='주류 출고량(수입분)')
fig.update_xaxes(title_text='연도', dtick=1)
fig.update_yaxes(title_text='출고량(kl)')
fig.update_layout(legend_title_text='주류별')



fig.show()
#15년 수입맥주 프로모션 이후 맥주 출고량 증가
# Out:
# <div>                            <div id="82078068-214b-4a02-9049-fee4a53d178f" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("82078068-214b-4a02-9049-fee4a53d178f")) {                    Plotly.newPlot(                        "82078068-214b-4a02-9049-fee4a53d178f",                        [{"hovertemplate":"\uc8fc\ub958\ubcc4=\ub9e5\uc8fc<br>index=%{x}<br>value=%{y}<extra></extra>","legendgroup":"\ub9e5\uc8fc","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines+markers","name":"\ub9e5\uc8fc","orientation":"v","showlegend":true,"x":[2010,2011,2012,2013,2014,2015,2016,2017,2018,2019,2020,2021,2022],"xaxis":"x","y":[48713,58993,74750,95211,119501,170919,220508,331211,387981,360132,277927,257932,228747],"yaxis":"y","typ
# ...

# %%
import plotly.express as px
fig_i=px.line(alcohol_external['맥주'], markers=True)
fig_i.update_layout(title_text='맥주 출고량(수입분)')
fig_i.update_xaxes(title_text='연도', dtick=1)
fig_i.update_yaxes(title_text='출고량(kl)')
fig_i.update_layout(showlegend=False)
fig_i.show()
# Out:
# <div>                            <div id="3f5eeaf8-ed3d-4ef3-82d0-26a001f8371a" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("3f5eeaf8-ed3d-4ef3-82d0-26a001f8371a")) {                    Plotly.newPlot(                        "3f5eeaf8-ed3d-4ef3-82d0-26a001f8371a",                        [{"hovertemplate":"variable=\ub9e5\uc8fc<br>index=%{x}<br>value=%{y}<extra></extra>","legendgroup":"\ub9e5\uc8fc","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines+markers","name":"\ub9e5\uc8fc","orientation":"v","showlegend":true,"x":[2010,2011,2012,2013,2014,2015,2016,2017,2018,2019,2020,2021,2022],"xaxis":"x","y":[48713,58993,74750,95211,119501,170919,220508,331211,387981,360132,277927,257932,228747],"yaxis":"y","type":"scatte
# ...

# %%
import plotly.express as px
fig=px.line(alcohol_external.drop(['맥주', '총 출고량'], axis=1), markers=True)
#fig.update_layout(title_text='맥주 제외 출고량(수입분)')
fig.update_xaxes(title_text='연도', dtick=1)
fig.update_yaxes(title_text='출고량(kl)')
fig.update_layout(legend_title_text='주류별')

fig.add_annotation(x=2022, y=27038,
            text="위스키 72.63% 증가",
            showarrow=True,
            arrowhead=1,
            font_size=15)

fig.show()
#혼술 트렌드 이후 포도주 증가
# Out:
# <div>                            <div id="fee1bc93-c199-4cb0-952f-89377ba104c3" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("fee1bc93-c199-4cb0-952f-89377ba104c3")) {                    Plotly.newPlot(                        "fee1bc93-c199-4cb0-952f-89377ba104c3",                        [{"hovertemplate":"\uc8fc\ub958\ubcc4=\ud3ec\ub3c4\uc8fc (\uc6d0\uc561\ud3ec\ud568)<br>index=%{x}<br>value=%{y}<extra></extra>","legendgroup":"\ud3ec\ub3c4\uc8fc (\uc6d0\uc561\ud3ec\ud568)","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines+markers","name":"\ud3ec\ub3c4\uc8fc (\uc6d0\uc561\ud3ec\ud568)","orientation":"v","showlegend":true,"x":[2010,2011,2012,2013,2014,2015,2016,2017,2018,2019,2020,2021,2022],"xaxis":"x","y":[24568
# ...

# %%
import plotly.express as px
fig=px.line(alcohol_external.drop(['맥주', '총 출고량'], axis=1), markers=True)
#fig.update_layout(title_text='맥주 제외 출고량(수입분)')
fig.update_xaxes(title_text='연도', dtick=1)
fig.update_yaxes(title_text='출고량(kl)')
fig.update_layout(legend_title_text='주류별')

# fig.add_annotation(x=2022, y=27038,
#             text="위스키 72.63% 증가",
#             showarrow=True,
#             arrowhead=1,
#             font_size=15)

fig.show()
#혼술 트렌드 이후 포도주 증가
# Out:
# <div>                            <div id="88a8ecf3-44d3-41f3-86c1-0a71eda33441" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("88a8ecf3-44d3-41f3-86c1-0a71eda33441")) {                    Plotly.newPlot(                        "88a8ecf3-44d3-41f3-86c1-0a71eda33441",                        [{"hovertemplate":"\uc8fc\ub958\ubcc4=\ud3ec\ub3c4\uc8fc (\uc6d0\uc561\ud3ec\ud568)<br>index=%{x}<br>value=%{y}<extra></extra>","legendgroup":"\ud3ec\ub3c4\uc8fc (\uc6d0\uc561\ud3ec\ud568)","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines+markers","name":"\ud3ec\ub3c4\uc8fc (\uc6d0\uc561\ud3ec\ud568)","orientation":"v","showlegend":true,"x":[2010,2011,2012,2013,2014,2015,2016,2017,2018,2019,2020,2021,2022],"xaxis":"x","y":[24568
# ...

# %%
alcohol_external['위스키'].tail(2)
# Out:
# 2021    15662
# 2022    27038
# Name: 위스키, dtype: int64

# %%
alcohol_external['위스키'].tail(2).pct_change()*100
# Out:
# 2021          NaN
# 2022    72.634402
# Name: 위스키, dtype: float64

# %%
#2000~2018 수입 주류
alcohol_import=pd.read_excel('./project_data/alcohol_import(2000_2018).xlsx', header=[2, 3], index_col=0, nrows=19, thousands=',')
alcohol_import=alcohol_import.T
alcohol_import
# Out:
#                맥주  포도주 (원액포함)  포도주 (유사포도주)   기타포도주  과실발효주 (사과술, 배술 등)  \
# 구분
# 2000 중량    8342.3      8052.5         79.7  1393.6              201.6
#      금액    5022.0     19803.0        153.0  4388.0              209.0
# 2001 중량   19465.3      8861.7         38.9  1156.1              170.0
#      금액   11866.0     23109.0        121.0  3670.0              206.0
# 2002 중량   20054.6     11522.4         39.8  1946.5              267.5
#      금액   12802.0     29431.0        123.0  6136.0              296.0
# 2003 중량   20709.8     13979.7         28.1  1582.9              422.7
#      금액   13664.0     45784.0         88.0  5898.0              558.0
# 2004 중량   21333.7     15897.7         43.3   880.4              359.2
#      금액   14848.0     57979.0        115.0  3220.0              694.0
# 2005 중량   22828.5     18984.1         71.6  1097.5              192.5
#      금액   16532.0     67654.0        176.0  3640.0              311.0
# ...

# %%
#각 연도 주류별 수입 중량
alcohol_import_weight=[]
for i in range(0, 37, 2):
    a=alcohol_import.iloc[i]
    alcohol_import_weight.append(a)

alcohol_import_weight
# Out:
# [맥주                    8342.3
#  포도주 (원액포함)            8052.5
#  포도주 (유사포도주)             79.7
#  기타포도주                 1393.6
#  과실발효주 (사과술, 배술 등)      201.6
#  청주기타발효주 (와인쿨러 등)        88.4
#  위스키                  20534.5
#  꼬냑                    1009.2
#  럼                      285.8
#  진                      155.7
#  보드카                    243.6
#  기타리큐르 (오가피 등)         1713.4
#  브랜디                     80.4
#  소주                      38.7
#  청주                     102.3
#  고량주                   1090.4
#  데낄라                    182.8
#  기타증류주                  168.4
#  기타곡물발효주                  0.4
#  Name: (2000, 중량), dtype: float64,
#  맥주                   19465.3
#  포도주 (원액포함)            8861.7
#  포도주 (유사포도주)             38.9
#  기타포도주                 1156.1
#  과실발효주 (사과술, 배술 등)      170.0
#  청주기타발효주 (와인쿨러 등)       731.1
#  위스키                  23607.3
#  꼬냑                    1014.4
#  럼                      322.0
#  진                      153.4
#  보드카                    293.6
# ...

# %%
#각 연도 주류별 수입 금액
alcohol_import_price=[]
for i in range(1, 38, 2):
    b=alcohol_import.iloc[i]
    alcohol_import_price.append(b)

alcohol_import_price
# Out:
# [맥주                     5022.0
#  포도주 (원액포함)            19803.0
#  포도주 (유사포도주)             153.0
#  기타포도주                  4388.0
#  과실발효주 (사과술, 배술 등)       209.0
#  청주기타발효주 (와인쿨러 등)        150.0
#  위스키                  180194.0
#  꼬냑                     8227.0
#  럼                       436.0
#  진                       226.0
#  보드카                     437.0
#  기타리큐르 (오가피 등)          3732.0
#  브랜디                     242.0
#  소주                       42.0
#  청주                      298.0
#  고량주                     769.0
#  데낄라                     854.0
#  기타증류주                   280.0
#  기타곡물발효주                   3.0
#  Name: (2000, 금액), dtype: float64,
#  맥주                    11866.0
#  포도주 (원액포함)            23109.0
#  포도주 (유사포도주)             121.0
#  기타포도주                  3670.0
#  과실발효주 (사과술, 배술 등)       206.0
#  청주기타발효주 (와인쿨러 등)       1192.0
#  위스키                  202355.0
#  꼬냑                     9548.0
#  럼                       627.0
#  진                       195.0
# ...

# %%
pd.DataFrame(alcohol_import_weight)
# Out:
#                맥주  포도주 (원액포함)  포도주 (유사포도주)   기타포도주  과실발효주 (사과술, 배술 등)  \
# 2000 중량    8342.3      8052.5         79.7  1393.6              201.6
# 2001 중량   19465.3      8861.7         38.9  1156.1              170.0
# 2002 중량   20054.6     11522.4         39.8  1946.5              267.5
# 2003 중량   20709.8     13979.7         28.1  1582.9              422.7
# 2004 중량   21333.7     15897.7         43.3   880.4              359.2
# 2005 중량   22828.5     18984.1         71.6  1097.5              192.5
# 2006 중량   26911.6     22194.4         89.8   746.4              351.2
# 2007 중량   35816.0     31810.2         39.0   803.9              470.8
# 2008 중량   43196.3     28795.3         25.5   667.5              558.3
# 2009 중량   41491.7     23009.4         30.1   280.9              467.1
# 2010 중량   48712.6     24568.1        336.7   395.0              561.4
# 2011 중량   58993.0     26004.0        140.5   416.4              485.5
# ...

# %%
#2018 수입 중량
alcohol_import_2018_weight=pd.DataFrame(alcohol_import_weight).reset_index().set_index('level_0').drop('level_1',axis=1)
alcohol_import_2018_weight
# Out:
#                맥주  포도주 (원액포함)  포도주 (유사포도주)   기타포도주  과실발효주 (사과술, 배술 등)  \
# level_0
# 2000       8342.3      8052.5         79.7  1393.6              201.6
# 2001      19465.3      8861.7         38.9  1156.1              170.0
# 2002      20054.6     11522.4         39.8  1946.5              267.5
# 2003      20709.8     13979.7         28.1  1582.9              422.7
# 2004      21333.7     15897.7         43.3   880.4              359.2
# 2005      22828.5     18984.1         71.6  1097.5              192.5
# 2006      26911.6     22194.4         89.8   746.4              351.2
# 2007      35816.0     31810.2         39.0   803.9              470.8
# 2008      43196.3     28795.3         25.5   667.5              558.3
# 2009      41491.7     23009.4         30.1   280.9              467.1
# 2010      48712.6     24568.1        336.7   395.0              561.4
# 2011      58993.0     26004.0        140.5   416.4              485.5
# ...

# %%
pd.DataFrame(alcohol_import_price)
# Out:
#                맥주  포도주 (원액포함)  포도주 (유사포도주)   기타포도주  과실발효주 (사과술, 배술 등)  \
# 2000 금액    5022.0     19803.0        153.0  4388.0              209.0
# 2001 금액   11866.0     23109.0        121.0  3670.0              206.0
# 2002 금액   12802.0     29431.0        123.0  6136.0              296.0
# 2003 금액   13664.0     45784.0         88.0  5898.0              558.0
# 2004 금액   14848.0     57979.0        115.0  3220.0              694.0
# 2005 금액   16532.0     67654.0        176.0  3640.0              311.0
# 2006 금액   20506.0     88606.0        209.0  3443.0              535.0
# 2007 금액   30579.0    150365.0        107.0  3479.0              639.0
# 2008 금액   39373.0    166513.0         77.0  2915.0              661.0
# 2009 금액   37156.0    112450.0         80.0  1159.0              656.0
# 2010 금액   43750.0    112888.0        648.0  1866.0              753.0
# 2011 금액   58445.0    132078.0        338.0  2042.0              730.0
# ...

# %%
#2018 수입 금액
alcohol_import_2018_price=pd.DataFrame(alcohol_import_price).reset_index().set_index('level_0').drop('level_1',axis=1)
alcohol_import_2018_price
# Out:
#                맥주  포도주 (원액포함)  포도주 (유사포도주)   기타포도주  과실발효주 (사과술, 배술 등)  \
# level_0
# 2000       5022.0     19803.0        153.0  4388.0              209.0
# 2001      11866.0     23109.0        121.0  3670.0              206.0
# 2002      12802.0     29431.0        123.0  6136.0              296.0
# 2003      13664.0     45784.0         88.0  5898.0              558.0
# 2004      14848.0     57979.0        115.0  3220.0              694.0
# 2005      16532.0     67654.0        176.0  3640.0              311.0
# 2006      20506.0     88606.0        209.0  3443.0              535.0
# 2007      30579.0    150365.0        107.0  3479.0              639.0
# 2008      39373.0    166513.0         77.0  2915.0              661.0
# 2009      37156.0    112450.0         80.0  1159.0              656.0
# 2010      43750.0    112888.0        648.0  1866.0              753.0
# 2011      58445.0    132078.0        338.0  2042.0              730.0
# ...

# %%
#2000~2018 수출 주류
alcohol_export_2018=pd.read_excel('./project_data/alcohol_export(2000_2018).xlsx', header=[2, 3], index_col=0, nrows=19)
alcohol_export_2018=alcohol_export_2018.T
alcohol_export_2018=alcohol_export_2018.dropna(axis=1)
alcohol_export_2018
# Out:
#                맥주        소주      청주      약주       탁주
# 구분
# 2000 중량   34614.5   62889.6  1497.2   148.2    949.5
#      금액   18955.0   87857.0  1973.0   529.0    895.0
# 2001 중량   44979.1   76642.1  1106.3   233.0    995.9
#      금액   25089.0   93509.0  1465.0   468.0    879.0
# 2002 중량   52862.7   80495.1   718.8   602.0   1526.5
#      금액   28874.0   97967.0  1141.0  1331.0   1192.0
# 2003 중량   55550.0   84655.8   965.8   987.0   1820.1
#      금액   29757.0  110272.0  1152.0  3107.0   1226.0
# 2004 중량   56791.1   95681.8   975.9   781.8   2245.4
#      금액   31071.0  130174.0  1186.0  2498.0   1617.0
# 2005 중량   66196.9   84625.2   932.9  1345.0   3027.9
#      금액   38112.0  116246.0  1196.0  2756.0   2166.0
# 2006 중량   69609.9   90624.5   523.8  1547.5   3763.7
#      금액   39212.0  118703.0   861.0  2768.0   2505.0
# 2007 중량   60388.9   87663.6   461.4  1161.1   4311.8
#      금액   34032.0  112359.0   880.0  2121.0   2905.0
# 2008 중량   74466.6   88835.5   589.7  1186.3   5457.2
# ...

# %%
#각 연도 주류별 수출 중량
alcohol_export_2018_weight=[]
for i in range(0, 37, 2):
    a=alcohol_export_2018.iloc[i]
    alcohol_export_2018_weight.append(a)

alcohol_export_2018_weight

pd.DataFrame(alcohol_export_2018_weight)
# Out:
#                맥주       소주      청주      약주       탁주
# 2000 중량   34614.5  62889.6  1497.2   148.2    949.5
# 2001 중량   44979.1  76642.1  1106.3   233.0    995.9
# 2002 중량   52862.7  80495.1   718.8   602.0   1526.5
# 2003 중량   55550.0  84655.8   965.8   987.0   1820.1
# 2004 중량   56791.1  95681.8   975.9   781.8   2245.4
# 2005 중량   66196.9  84625.2   932.9  1345.0   3027.9
# 2006 중량   69609.9  90624.5   523.8  1547.5   3763.7
# 2007 중량   60388.9  87663.6   461.4  1161.1   4311.8
# 2008 중량   74466.6  88835.5   589.7  1186.3   5457.2
# 2009 중량   73182.0  81170.7   559.0   743.6   7405.4
# 2010 중량   81315.4  79788.3   610.6   639.3  19414.6
# 2011 중량  104218.1  69367.0   511.7   608.6  43082.0
# 2012 중량  104920.4  77665.2   625.9   666.6  30658.2
# 2013 중량  113155.3  77615.0   675.3   527.1  18221.9
# 2014 중량  111003.8  74338.5   679.7   497.0  15470.0
# 2015 중량  123963.7  72136.5   691.3   396.9  13892.8
# 2016 중량  131484.6  69798.6   449.5   283.1  13654.4
# ...

# %%
#2018 수출 중량
alcohol_export_2018_weight=pd.DataFrame(alcohol_export_2018_weight).reset_index().set_index('level_0').drop('level_1',axis=1)
alcohol_export_2018_weight
# Out:
#                맥주       소주      청주      약주       탁주
# level_0
# 2000      34614.5  62889.6  1497.2   148.2    949.5
# 2001      44979.1  76642.1  1106.3   233.0    995.9
# 2002      52862.7  80495.1   718.8   602.0   1526.5
# 2003      55550.0  84655.8   965.8   987.0   1820.1
# 2004      56791.1  95681.8   975.9   781.8   2245.4
# 2005      66196.9  84625.2   932.9  1345.0   3027.9
# 2006      69609.9  90624.5   523.8  1547.5   3763.7
# 2007      60388.9  87663.6   461.4  1161.1   4311.8
# 2008      74466.6  88835.5   589.7  1186.3   5457.2
# 2009      73182.0  81170.7   559.0   743.6   7405.4
# 2010      81315.4  79788.3   610.6   639.3  19414.6
# 2011     104218.1  69367.0   511.7   608.6  43082.0
# 2012     104920.4  77665.2   625.9   666.6  30658.2
# 2013     113155.3  77615.0   675.3   527.1  18221.9
# 2014     111003.8  74338.5   679.7   497.0  15470.0
# 2015     123963.7  72136.5   691.3   396.9  13892.8
# 2016     131484.6  69798.6   449.5   283.1  13654.4
# ...

# %%
#각 연도 주류별 수출 금액
alcohol_export_2018_price=[]
for i in range(1, 38, 2):
    b=alcohol_export_2018.iloc[i]
    alcohol_export_2018_price.append(b)

alcohol_export_2018_price

pd.DataFrame(alcohol_export_2018_price)
# Out:
#                맥주        소주      청주      약주       탁주
# 2000 금액   18955.0   87857.0  1973.0   529.0    895.0
# 2001 금액   25089.0   93509.0  1465.0   468.0    879.0
# 2002 금액   28874.0   97967.0  1141.0  1331.0   1192.0
# 2003 금액   29757.0  110272.0  1152.0  3107.0   1226.0
# 2004 금액   31071.0  130174.0  1186.0  2498.0   1617.0
# 2005 금액   38112.0  116246.0  1196.0  2756.0   2166.0
# 2006 금액   39212.0  118703.0   861.0  2768.0   2505.0
# 2007 금액   34032.0  112359.0   880.0  2121.0   2905.0
# 2008 금액   43284.0  124108.0   971.0  2389.0   4422.0
# 2009 금액   41831.0  112931.0   930.0  1500.0   6277.0
# 2010 금액   46836.0  123056.0  1010.0  1310.0  19095.0
# 2011 금액   65397.0  114345.0  1067.0  1345.0  52735.0
# 2012 금액   67814.0  126813.0  1091.0  1463.0  36893.0
# 2013 금액   72250.0  107513.0  1269.0  1196.0  18862.0
# 2014 금액   73181.0   99513.0  1374.0  1136.0  15352.0
# 2015 금액   84455.0   87759.0   1,431   901.0  12902.0
# 2016 금액   90864.0   93017.0   840.0   709.0  12868.0
# ...

# %%
#2018 수출 금액
alcohol_export_2018_price=pd.DataFrame(alcohol_export_2018_price).reset_index().set_index('level_0').drop('level_1',axis=1)
alcohol_export_2018_price
# Out:
#                맥주        소주      청주      약주       탁주
# level_0
# 2000      18955.0   87857.0  1973.0   529.0    895.0
# 2001      25089.0   93509.0  1465.0   468.0    879.0
# 2002      28874.0   97967.0  1141.0  1331.0   1192.0
# 2003      29757.0  110272.0  1152.0  3107.0   1226.0
# 2004      31071.0  130174.0  1186.0  2498.0   1617.0
# 2005      38112.0  116246.0  1196.0  2756.0   2166.0
# 2006      39212.0  118703.0   861.0  2768.0   2505.0
# 2007      34032.0  112359.0   880.0  2121.0   2905.0
# 2008      43284.0  124108.0   971.0  2389.0   4422.0
# 2009      41831.0  112931.0   930.0  1500.0   6277.0
# 2010      46836.0  123056.0  1010.0  1310.0  19095.0
# 2011      65397.0  114345.0  1067.0  1345.0  52735.0
# 2012      67814.0  126813.0  1091.0  1463.0  36893.0
# 2013      72250.0  107513.0  1269.0  1196.0  18862.0
# 2014      73181.0   99513.0  1374.0  1136.0  15352.0
# 2015      84455.0   87759.0   1,431   901.0  12902.0
# 2016      90864.0   93017.0   840.0   709.0  12868.0
# ...

# %%
#2019 주류 수출입
alcohol_trade_2019=pd.read_excel('./project_data/alcohol_trade_2019.xlsx', header=[2, 3, 4], index_col=0, nrows=19)
alcohol_trade_2019
# Out:
# 구분                 2019년 합계                                 1월          \
#                          수출                수입               수출
#                          중량      금액        중량      금액       중량      금액
# 맥주                 209280.8  145936  360131.9  280881  13455.6  9392.0
# 포도주 (원액포함)            175.7     419   43495.3  259200     85.4   152.0
# 포도주 (유사포도주)             0.0       0    1487.9    3115      0.0     0.0
# 기타포도주                   8.7     414     320.4    1342      0.0     0.0
# 과실발효주 (사과술, 배술 등)    1161.4    3262    6580.8    7133     88.3   255.0
# 청주기타발효주 (와인쿨러 등)       83.5     261    3432.7    4442      0.9     5.0
# 위스키                  1268.2    8016   19836.1  153933     56.6   414.0
# 꼬냑                      0.9      36     126.3    4658      0.0     NaN
# 럼                     439.5    1614    1042.2    2586     27.2   108.0
# 진                    1181.0    2085     497.6    2614    530.9   824.0
# ...

# %%
alcohol_trade_2019.T
# Out:
#                       맥주  포도주 (원액포함)  포도주 (유사포도주)   기타포도주  과실발효주 (사과술, 배술 등)  \
# 구분
# 2019년 합계 수출 중량  209280.8       175.7          0.0     8.7             1161.4
#             금액  145936.0       419.0          0.0   414.0             3262.0
#          수입 중량  360131.9     43495.3       1487.9   320.4             6580.8
#             금액  280881.0    259200.0       3115.0  1342.0             7133.0
# 1월       수출 중량   13455.6        85.4          0.0     0.0               88.3
#             금액    9392.0       152.0          0.0     0.0              255.0
#          수입 중량   34381.6      4593.0        231.8    62.9              380.5
#             금액   27500.0     25835.0        475.0   289.0              444.0
# 2월       수출 중량   14534.6         1.1          0.0     8.2              119.4
#             금액   10640.0        10.0          0.0   397.0              275.0
#          수입 중량   22605.7      2759.5        129.3     6.1              433.7
# ...

# %%
alcohol_trade_2019=alcohol_trade_2019.T.loc['2019년 합계']
alcohol_trade_2019
# Out:
#              맥주  포도주 (원액포함)  포도주 (유사포도주)   기타포도주  과실발효주 (사과술, 배술 등)  \
# 수출 중량  209280.8       175.7          0.0     8.7             1161.4
#    금액  145936.0       419.0          0.0   414.0             3262.0
# 수입 중량  360131.9     43495.3       1487.9   320.4             6580.8
#    금액  280881.0    259200.0       3115.0  1342.0             7133.0
#
#        청주기타발효주 (와인쿨러 등)       위스키      꼬냑       럼       진     보드카  \
# 수출 중량              83.5    1268.2     0.9   439.5  1181.0  1679.0
#    금액             261.0    8016.0    36.0  1614.0  2085.0  3268.0
# 수입 중량            3432.7   19836.1   126.3  1042.2   497.6  3400.7
#    금액            4442.0  153933.0  4658.0  2586.0  2614.0  8797.0
#
#        기타리큐르 (오가피 등)    브랜디       소주       청주      고량주     데낄라    기타증류주  \
# 수출 중량        18568.7    0.1  65812.4    357.4      3.4     0.0   7228.5
#    금액        29070.0    1.0  89744.0    768.0     10.0     0.0  12899.0
# 수입 중량         5834.9   70.3    129.4   4110.6   7464.4   759.4   3683.0
# ...

# %%
#2019년 수입 중량
alcohol_import_2019_weight=pd.DataFrame(alcohol_trade_2019.loc['수입'].loc['중량']).T
alcohol_import_2019_weight=alcohol_import_2019_weight.rename(index={'중량' : '2019'})
alcohol_import_2019_weight
# Out:
#             맥주  포도주 (원액포함)  포도주 (유사포도주)  기타포도주  과실발효주 (사과술, 배술 등)  \
# 2019  360131.9     43495.3       1487.9  320.4             6580.8
#
#       청주기타발효주 (와인쿨러 등)      위스키     꼬냑       럼      진     보드카  기타리큐르 (오가피 등)  \
# 2019            3432.7  19836.1  126.3  1042.2  497.6  3400.7         5834.9
#
#        브랜디     소주      청주     고량주    데낄라   기타증류주  기타곡물발효주
# 2019  70.3  129.4  4110.6  7464.4  759.4  3683.0   2119.6

# %%
#2019년 수입 금액
alcohol_import_2019_price=pd.DataFrame(alcohol_trade_2019.loc['수입'].loc['금액']).T
alcohol_import_2019_price=alcohol_import_2019_price.rename(index={'금액' : '2019'})
alcohol_import_2019_price
# Out:
#             맥주  포도주 (원액포함)  포도주 (유사포도주)   기타포도주  과실발효주 (사과술, 배술 등)  \
# 2019  280881.0    259200.0       3115.0  1342.0             7133.0
#
#       청주기타발효주 (와인쿨러 등)       위스키      꼬냑       럼       진     보드카  \
# 2019            4442.0  153933.0  4658.0  2586.0  2614.0  8797.0
#
#       기타리큐르 (오가피 등)    브랜디     소주       청주      고량주     데낄라   기타증류주  기타곡물발효주
# 2019        18719.0  398.0  686.0  15797.0  12137.0  4440.0  5196.0   1788.0

# %%
#2019년 수출 중량
alcohol_export_2019_weight=pd.DataFrame(alcohol_trade_2019.loc['수출'].loc['중량']).T
alcohol_export_2019_weight=alcohol_export_2019_weight.rename(index={'중량' : '2019'})
alcohol_export_2019_weight
# Out:
#             맥주  포도주 (원액포함)  포도주 (유사포도주)  기타포도주  과실발효주 (사과술, 배술 등)  \
# 2019  209280.8       175.7          0.0    8.7             1161.4
#
#       청주기타발효주 (와인쿨러 등)     위스키   꼬냑      럼       진     보드카  기타리큐르 (오가피 등)  \
# 2019              83.5  1268.2  0.9  439.5  1181.0  1679.0        18568.7
#
#       브랜디       소주     청주  고량주  데낄라   기타증류주  기타곡물발효주
# 2019  0.1  65812.4  357.4  3.4  0.0  7228.5  54380.2

# %%
#2019년 수출 금액
alcohol_export_2019_price=pd.DataFrame(alcohol_trade_2019.loc['수출'].loc['금액']).T
alcohol_export_2019_price=alcohol_export_2019_price.rename(index={'금액' : '2019'})
alcohol_export_2019_price
# Out:
#             맥주  포도주 (원액포함)  포도주 (유사포도주)  기타포도주  과실발효주 (사과술, 배술 등)  \
# 2019  145936.0       419.0          0.0  414.0             3262.0
#
#       청주기타발효주 (와인쿨러 등)     위스키    꼬냑       럼       진     보드카  기타리큐르 (오가피 등)  \
# 2019             261.0  8016.0  36.0  1614.0  2085.0  3268.0        29070.0
#
#       브랜디       소주     청주   고량주  데낄라    기타증류주  기타곡물발효주
# 2019  1.0  89744.0  768.0  10.0  0.0  12899.0  35664.0

# %%
#2020 주류 수출입
alcohol_trade_2020=pd.read_excel('./project_data/alcohol_trade_2020.xlsx', header=[2, 3, 4], index_col=0, nrows=19)
alcohol_trade_2020
# Out:
# 구분                     1월                             2월                 \
#                        수출             수입              수출             수입
#                        중량    금액       중량     금액       중량    금액       중량
# 맥주                 9005.1  5753  20995.5  17089  12251.6  8537  21754.9
# 포도주 (원액포함)           23.0    54   4394.7  25692     21.0    36   3054.0
# 포도주 (유사포도주)           0.0     0     76.1    171      0.0     0    106.0
# 기타포도주                 0.0     0     28.3    123      0.0     0      4.9
# 과실발효주 (사과술, 배술 등)   115.2   286   1131.8   1215     93.0   214   1204.5
# 청주기타발효주 (와인쿨러 등)      0.5     1    147.3    195      0.0     0    286.9
# 위스키                  49.8   263   1220.8   7666     41.8   228   1137.4
# 꼬냑                    0.0     0      9.0    381      0.0     0      9.4
# 럼                     0.0     0     77.1    204      0.0     0     28.0
# 진                     0.0     0     48.3    244      0.0     0     33.2
# ...

# %%
alcohol_trade_2020.T
# Out:
#                 맥주  포도주 (원액포함)  포도주 (유사포도주)  기타포도주  과실발효주 (사과술, 배술 등)  \
# 구분
# 1월  수출 중량   9005.1        23.0          0.0    0.0              115.2
#        금액   5753.0        54.0          0.0    0.0              286.0
#     수입 중량  20995.5      4394.7         76.1   28.3             1131.8
#        금액  17089.0     25692.0        171.0  123.0             1215.0
# 2월  수출 중량  12251.6        21.0          0.0    0.0               93.0
#        금액   8537.0        36.0          0.0    0.0              214.0
#     수입 중량  21754.9      3054.0        106.0    4.9             1204.5
#        금액  17082.0     17004.0        221.0   46.0             1250.0
# 3월  수출 중량  12389.5         7.6          0.0    0.0              137.7
#        금액   8307.0        31.0          0.0    0.0              366.0
#     수입 중량  21142.5      3281.7        170.7   34.7                7.5
#        금액  16676.0     20202.0        326.0  127.0               23.0
# ...

# %%
alcohol_trade_2020.T.iloc[47]
# Out:
# 맥주                   18837.0
# 포도주 (원액포함)           42500.0
# 포도주 (유사포도주)            398.0
# 기타포도주                   18.0
# 과실발효주 (사과술, 배술 등)     1578.0
# 청주기타발효주 (와인쿨러 등)       591.0
# 위스키                  20165.0
# 꼬냑                      85.2
# 럼                      163.0
# 진                      452.0
# 보드카                    567.0
# 기타리큐르 (오가피 등)         1433.0
# 브랜디                     34.0
# 소주                      44.0
# 청주                    1447.0
# 고량주                   1413.0
# 데낄라                    267.0
# 기타증류주                  264.0
# 기타곡물발효주                511.0
# Name: (12월, 수입, 금액), dtype: float64

# %%
#2020년 수출 중량
alcohol_export_2020_weight=[]
for i in range(0, 47, 4):
    c=alcohol_trade_2020.T.iloc[i]
    alcohol_export_2020_weight.append(c)

alcohol_export_2020_weight
# Out:
# [맥주                   9005.1
#  포도주 (원액포함)             23.0
#  포도주 (유사포도주)             0.0
#  기타포도주                   0.0
#  과실발효주 (사과술, 배술 등)     115.2
#  청주기타발효주 (와인쿨러 등)        0.5
#  위스키                    49.8
#  꼬냑                      0.0
#  럼                       0.0
#  진                       0.0
#  보드카                     9.4
#  기타리큐르 (오가피 등)        1406.6
#  브랜디                     0.0
#  소주                   6025.6
#  청주                     15.7
#  고량주                     0.0
#  데낄라                     0.0
#  기타증류주                 795.1
#  기타곡물발효주              4434.7
#  Name: (1월, 수출, 중량), dtype: float64,
#  맥주                   12251.6
#  포도주 (원액포함)              21.0
#  포도주 (유사포도주)              0.0
#  기타포도주                    0.0
#  과실발효주 (사과술, 배술 등)       93.0
#  청주기타발효주 (와인쿨러 등)         0.0
#  위스키                     41.8
#  꼬냑                       0.0
#  럼                        0.0
#  진                        0.0
#  보드카                     62.8
# ...

# %%
pd.DataFrame(alcohol_export_2020_weight)
# Out:
#                 맥주  포도주 (원액포함)  포도주 (유사포도주)  기타포도주  과실발효주 (사과술, 배술 등)  \
# 1월  수출 중량   9005.1        23.0          0.0    0.0              115.2
# 2월  수출 중량  12251.6        21.0          0.0    0.0               93.0
# 3월  수출 중량  12389.5         7.6          0.0    0.0              137.7
# 4월  수출 중량   6565.3        30.3          0.0    0.0               71.0
# 5월  수출 중량   5743.7         1.7          0.0    0.0               53.2
# 6월  수출 중량  10151.9         0.1          0.0    9.1              109.6
# 7월  수출 중량  13583.5         0.7          0.0    0.0              189.7
# 8월  수출 중량   7543.9         0.7          0.0    0.0              228.2
# 9월  수출 중량   8662.8        18.9          0.0    0.0              173.1
# 10월 수출 중량   6664.0        24.4          0.0    0.0              200.1
# 11월 수출 중량  10764.1         0.5          0.0    0.0              184.6
# 12월 수출 중량   6010.7        18.9          0.0    0.0              147.8
#
# ...

# %%
pd.DataFrame(alcohol_export_2020_weight).sum()
# Out:
# 맥주                   109336.1
# 포도주 (원액포함)              147.8
# 포도주 (유사포도주)               0.0
# 기타포도주                     9.1
# 과실발효주 (사과술, 배술 등)      1703.2
# 청주기타발효주 (와인쿨러 등)         26.0
# 위스키                     504.3
# 꼬냑                        0.0
# 럼                         0.1
# 진                       259.5
# 보드카                     933.6
# 기타리큐르 (오가피 등)         32090.4
# 브랜디                       0.1
# 소주                    62185.7
# 청주                      290.6
# 고량주                       3.1
# 데낄라                       0.0
# 기타증류주                  5974.2
# 기타곡물발효주               54904.3
# dtype: float64

# %%
alcohol_export_2020_weight=pd.DataFrame(pd.DataFrame(alcohol_export_2020_weight).sum()).T.rename(index={0 : '2020'})
alcohol_export_2020_weight
# Out:
#             맥주  포도주 (원액포함)  포도주 (유사포도주)  기타포도주  과실발효주 (사과술, 배술 등)  \
# 2020  109336.1       147.8          0.0    9.1             1703.2
#
#       청주기타발효주 (와인쿨러 등)    위스키   꼬냑    럼      진    보드카  기타리큐르 (오가피 등)  브랜디  \
# 2020              26.0  504.3  0.0  0.1  259.5  933.6        32090.4  0.1
#
#            소주     청주  고량주  데낄라   기타증류주  기타곡물발효주
# 2020  62185.7  290.6  3.1  0.0  5974.2  54904.3

# %%
#2020 수출 금액
alcohol_export_2020_price=[]
for i in range(1, 48, 4):
    c=alcohol_trade_2020.T.iloc[i]
    alcohol_export_2020_price.append(c)

alcohol_export_2020_price
# Out:
# [맥주                   5753.0
#  포도주 (원액포함)             54.0
#  포도주 (유사포도주)             0.0
#  기타포도주                   0.0
#  과실발효주 (사과술, 배술 등)     286.0
#  청주기타발효주 (와인쿨러 등)        1.0
#  위스키                   263.0
#  꼬냑                      0.0
#  럼                       0.0
#  진                       0.0
#  보드카                    18.0
#  기타리큐르 (오가피 등)        2048.0
#  브랜디                     0.0
#  소주                   7889.0
#  청주                     47.0
#  고량주                     0.0
#  데낄라                     0.0
#  기타증류주                1323.0
#  기타곡물발효주              2825.0
#  Name: (1월, 수출, 금액), dtype: float64,
#  맥주                   8537.0
#  포도주 (원액포함)             36.0
#  포도주 (유사포도주)             0.0
#  기타포도주                   0.0
#  과실발효주 (사과술, 배술 등)     214.0
#  청주기타발효주 (와인쿨러 등)        0.0
#  위스키                   228.0
#  꼬냑                      0.0
#  럼                       0.0
#  진                       0.0
#  보드카                   112.0
#  기타리큐르 (오가피 등)        2255.0
# ...

# %%
alcohol_export_2020_price=pd.DataFrame(pd.DataFrame(alcohol_export_2020_price).sum()).T.rename(index={0 : '2020'})
alcohol_export_2020_price
# Out:
#            맥주  포도주 (원액포함)  포도주 (유사포도주)  기타포도주  과실발효주 (사과술, 배술 등)  \
# 2020  68529.0       337.0          0.0    8.0             3769.0
#
#       청주기타발효주 (와인쿨러 등)     위스키   꼬냑    럼      진     보드카  기타리큐르 (오가피 등)  브랜디  \
# 2020             260.0  3058.0  0.0  2.0  467.0  1663.0        49663.0  0.0
#
#            소주     청주   고량주  데낄라    기타증류주  기타곡물발효주
# 2020  86045.0  663.0  17.0  0.0  10164.0  36926.0

# %%
#2020 수입 중량
alcohol_import_2020_weight=[]
for i in range(2, 48, 4):
    c=alcohol_trade_2020.T.iloc[i]
    alcohol_import_2020_weight.append(c)

alcohol_import_2020_weight
# Out:
# [맥주                   20995.5
#  포도주 (원액포함)            4394.7
#  포도주 (유사포도주)             76.1
#  기타포도주                   28.3
#  과실발효주 (사과술, 배술 등)     1131.8
#  청주기타발효주 (와인쿨러 등)       147.3
#  위스키                   1220.8
#  꼬냑                       9.0
#  럼                       77.1
#  진                       48.3
#  보드카                    130.4
#  기타리큐르 (오가피 등)          545.3
#  브랜디                      1.9
#  소주                       2.0
#  청주                     181.6
#  고량주                    895.6
#  데낄라                     40.2
#  기타증류주                  138.4
#  기타곡물발효주                219.6
#  Name: (1월, 수입, 중량), dtype: float64,
#  맥주                   21754.9
#  포도주 (원액포함)            3054.0
#  포도주 (유사포도주)            106.0
#  기타포도주                    4.9
#  과실발효주 (사과술, 배술 등)     1204.5
#  청주기타발효주 (와인쿨러 등)       286.9
#  위스키                   1137.4
#  꼬냑                       9.4
#  럼                       28.0
#  진                       33.2
#  보드카                    155.1
# ...

# %%
alcohol_import_2020_weight=pd.DataFrame(pd.DataFrame(alcohol_import_2020_weight).sum()).T.rename(index={0 : '2020'})
alcohol_import_2020_weight
# Out:
#             맥주  포도주 (원액포함)  포도주 (유사포도주)  기타포도주  과실발효주 (사과술, 배술 등)  \
# 2020  277931.5     54192.9       1587.3  284.1            11427.7
#
#       청주기타발효주 (와인쿨러 등)      위스키     꼬냑      럼      진     보드카  기타리큐르 (오가피 등)  \
# 2020            4914.8  15922.9  136.8  749.0  500.2  2037.1         5002.0
#
#        브랜디     소주      청주     고량주    데낄라   기타증류주  기타곡물발효주
# 2020  70.8  172.5  2378.9  7427.0  434.1  3824.2   4893.3

# %%
#2020 수입 금액
alcohol_import_2020_price=[]
for i in range(3, 48, 4):
    c=alcohol_trade_2020.T.iloc[i]
    alcohol_import_2020_price.append(c)

alcohol_import_2020_price
# Out:
# [맥주                   17089.0
#  포도주 (원액포함)           25692.0
#  포도주 (유사포도주)            171.0
#  기타포도주                  123.0
#  과실발효주 (사과술, 배술 등)     1215.0
#  청주기타발효주 (와인쿨러 등)       195.0
#  위스키                   7666.0
#  꼬냑                     381.0
#  럼                      204.0
#  진                      244.0
#  보드카                    341.0
#  기타리큐르 (오가피 등)         2024.0
#  브랜디                      3.0
#  소주                      18.0
#  청주                     745.0
#  고량주                   1678.0
#  데낄라                    240.0
#  기타증류주                  261.0
#  기타곡물발효주                146.0
#  Name: (1월, 수입, 금액), dtype: float64,
#  맥주                   17082.0
#  포도주 (원액포함)           17004.0
#  포도주 (유사포도주)            221.0
#  기타포도주                   46.0
#  과실발효주 (사과술, 배술 등)     1250.0
#  청주기타발효주 (와인쿨러 등)       307.0
#  위스키                   7090.0
#  꼬냑                     268.0
#  럼                       97.0
#  진                      159.0
#  보드카                    377.0
# ...

# %%
alcohol_import_2020_price=pd.DataFrame(pd.DataFrame(alcohol_import_2020_price).sum()).T.rename(index={0 : '2020'})
alcohol_import_2020_price
# Out:
#             맥주  포도주 (원액포함)  포도주 (유사포도주)   기타포도주  과실발효주 (사과술, 배술 등)  \
# 2020  226409.0    330187.0       3331.0  1135.0            12513.0
#
#       청주기타발효주 (와인쿨러 등)       위스키      꼬냑       럼       진     보드카  \
# 2020            5507.0  131554.0  4349.2  2046.0  2894.0  5557.0
#
#       기타리큐르 (오가피 등)    브랜디     소주       청주      고량주     데낄라   기타증류주  기타곡물발효주
# 2020        15792.0  443.0  736.0  11736.0  12150.0  2530.0  5031.0   3402.0

# %%
#2021 주류 수출입
alcohol_trade_2021=pd.read_excel('./project_data/alcohol_trade_2021.xlsx', header=[2, 3, 4], index_col=0, nrows=23)
alcohol_trade_2021.T
# Out:
#                 맥주  포도주 (원액포함)  포도주 (유사포도주)  기타포도주  과실발효주 (사과술, 배술 등)  \
# 구분
# 1월  수출 중량   5468.1         8.2          0.0    0.0              247.5
#        금액   3263.0        31.0          0.0    0.0              398.0
#     수입 중량  21434.4      6297.7        127.4   54.6             1945.1
#        금액  17685.0     44801.0        362.0  318.0             2244.0
# 2월  수출 중량   5173.9         0.6          0.0    0.0              188.8
#        금액   3182.0         8.0          0.0    0.0              458.0
#     수입 중량  17769.9      4988.4         86.8    9.2             1127.6
#        금액  15382.0     37135.0        222.0   40.0             1312.0
# 3월  수출 중량   9847.2        23.8          0.0    0.0              324.8
#        금액   5878.0        40.0          0.0    0.0              763.0
#     수입 중량  16592.3      6659.1        209.2   48.4              495.0
#        금액  14161.0     46001.0        455.0  175.0              618.0
# ...

# %%
#2021년 수출 중량
alcohol_export_2021_weight=[]
for i in range(0, 47, 4):
    d=alcohol_trade_2021.T.iloc[i]
    alcohol_export_2021_weight.append(d)

alcohol_export_2021_weight
# Out:
# [맥주                   5468.1
#  포도주 (원액포함)              8.2
#  포도주 (유사포도주)             0.0
#  기타포도주                   0.0
#  과실발효주 (사과술, 배술 등)     247.5
#  청주기타발효주 (와인쿨러 등)        0.4
#  위스키                    33.1
#  스카시 위스키                33.1
#  버본 위스키                  0.0
#  라이 위스키                  0.0
#  기타                      0.0
#  꼬냑                      0.0
#  럼                       0.0
#  진                       0.1
#  보드카                     0.0
#  기타리큐르 (오가피 등)        4277.2
#  브랜디                     0.0
#  소주                   5024.9
#  청주                     26.4
#  고량주                     0.6
#  데낄라                     0.0
#  기타증류주                 331.7
#  기타곡물발효주              2864.2
#  Name: (1월, 수출, 중량), dtype: float64,
#  맥주                   5173.9
#  포도주 (원액포함)              0.6
#  포도주 (유사포도주)             0.0
#  기타포도주                   0.0
#  과실발효주 (사과술, 배술 등)     188.8
#  청주기타발효주 (와인쿨러 등)        9.2
#  위스키                    33.5
#  스카시 위스키                33.5
# ...

# %%
alcohol_export_2021_weight=pd.DataFrame(pd.DataFrame(alcohol_export_2021_weight).sum()).T.rename(index={0 : '2021'})
alcohol_export_2021_weight
# Out:
#            맥주  포도주 (원액포함)  포도주 (유사포도주)  기타포도주  과실발효주 (사과술, 배술 등)  \
# 2021  95976.0       144.5          0.0    0.0             2408.5
#
#       청주기타발효주 (와인쿨러 등)    위스키  스카시 위스키  버본 위스키  라이 위스키  ...    진  보드카  \
# 2021              28.6  181.7    179.0     0.0     0.0  ...  3.6  5.4
#
#       기타리큐르 (오가피 등)  브랜디       소주     청주  고량주  데낄라   기타증류주  기타곡물발효주
# 2021        50588.3  0.0  59529.5  371.4  6.1  0.0  2016.9  41409.9
#
# [1 rows x 23 columns]

# %%
#2021 수출 금액
alcohol_export_2021_price=[]
for i in range(1, 48, 4):
    d=alcohol_trade_2021.T.iloc[i]
    alcohol_export_2021_price.append(d)

alcohol_export_2021_price=pd.DataFrame(pd.DataFrame(alcohol_export_2021_price).sum()).T.rename(index={0 : '2021'})
alcohol_export_2021_price
# Out:
#            맥주  포도주 (원액포함)  포도주 (유사포도주)  기타포도주  과실발효주 (사과술, 배술 등)  \
# 2021  59981.0       281.0          0.0    0.0             5751.0
#
#       청주기타발효주 (와인쿨러 등)    위스키  스카시 위스키  버본 위스키  라이 위스키  ...     진   보드카  \
# 2021             214.0  999.0    981.0     0.0     0.0  ...  50.0  16.0
#
#       기타리큐르 (오가피 등)  브랜디       소주     청주   고량주  데낄라   기타증류주  기타곡물발효주
# 2021        80917.0  0.0  82762.0  845.0  13.0  0.0  4143.0  29391.0
#
# [1 rows x 23 columns]

# %%
#2021 수입 중량
alcohol_import_2021_weight=[]
for i in range(2, 48, 4):
    d=alcohol_trade_2021.T.iloc[i]
    alcohol_import_2021_weight.append(d)

alcohol_import_2021_weight=pd.DataFrame(pd.DataFrame(alcohol_import_2021_weight).sum()).T.rename(index={0 : '2021'})
alcohol_import_2021_weight
# Out:
#             맥주  포도주 (원액포함)  포도주 (유사포도주)  기타포도주  과실발효주 (사과술, 배술 등)  \
# 2021  257932.1     76575.3       1799.2  303.3            14709.0
#
#       청주기타발효주 (와인쿨러 등)      위스키  스카시 위스키  버본 위스키  라이 위스키  ...      진     보드카  \
# 2021            8664.6  15661.4   5677.0  1167.6    17.3  ...  548.1  2266.4
#
#       기타리큐르 (오가피 등)    브랜디    소주      청주     고량주    데낄라   기타증류주  기타곡물발효주
# 2021         4995.7  101.2  94.8  3108.7  7122.6  454.0  6029.8   6508.2
#
# [1 rows x 23 columns]

# %%
#2021 수입 금액
alcohol_import_2021_price=[]
for i in range(3, 48, 4):
    d=alcohol_trade_2021.T.iloc[i]
    alcohol_import_2021_price.append(d)

alcohol_import_2021_price=pd.DataFrame(pd.DataFrame(alcohol_import_2021_price).sum()).T.rename(index={0 : '2021'})
alcohol_import_2021_price
# Out:
#             맥주  포도주 (원액포함)  포도주 (유사포도주)   기타포도주  과실발효주 (사과술, 배술 등)  \
# 2021  223099.0    559811.0       4225.0  1518.0            17014.0
#
#       청주기타발효주 (와인쿨러 등)       위스키   스카시 위스키  버본 위스키  라이 위스키  ...       진  \
# 2021           10507.0  175348.0  121409.0  9118.0   514.0  ...  3517.0
#
#          보드카  기타리큐르 (오가피 등)    브랜디     소주       청주      고량주     데낄라   기타증류주  \
# 2021  6986.0        18031.0  527.0  699.0  15590.0  12720.0  2989.0  6550.0
#
#       기타곡물발효주
# 2021   5335.0
#
# [1 rows x 23 columns]

# %%
#2022 주류 수출입
alcohol_trade_2022=pd.read_excel('./project_data/alcohol_trade_2022.xlsx', header=[2, 3, 4], index_col=0, nrows=23)
alcohol_trade_2022.T
# Out:
#                 맥주  포도주 (원액포함)  포도주 (유사포도주)  기타포도주  과실발효주 (사과술, 배술 등)  \
# 구분
# 1월  수출 중량   8641.2        19.2          0.0    0.0              204.1
#        금액   5229.0        28.0          0.0    0.0              493.0
#     수입 중량  22326.0      5992.7        119.0   35.1              698.9
#        금액  18300.0     46739.0        365.0  164.0              894.0
# 2월  수출 중량   7778.9         1.1          0.0    0.0              119.1
#        금액   5430.0         3.0          0.0    0.0              288.0
#     수입 중량  18131.2      5629.0        120.6    6.1             1780.3
#        금액  15685.0     43459.0        342.0   28.0             1969.0
# 3월  수출 중량   7560.3         0.6          0.0    0.6              380.3
#        금액   5389.0         2.0          0.0    3.0              820.0
#     수입 중량  29016.9      5779.1        139.0   37.9              549.3
#        금액  23915.0     49951.0        295.0  162.0              581.0
# ...

# %%
alcohol_trade_2022.T.iloc[44]
# Out:
# 맥주                   7222.1
# 포도주 (원액포함)              6.7
# 포도주 (유사포도주)             0.0
# 기타포도주                   0.0
# 과실발효주 (사과술, 배술 등)     188.4
# 청주기타발효주 (와인쿨러 등)       24.7
# 위스키                    19.9
# 스카시 위스키                14.5
# 버본 위스키                  0.0
# 라이 위스키                  0.0
# 기타                      5.4
# 꼬냑                      0.0
# 럼                       0.0
# 진                       0.0
# 보드카                     0.0
# 기타리큐르 (오가피 등)        4528.4
# 브랜디                     0.0
# 소주                   6579.1
# 청주                     38.8
# 고량주                     0.0
# 데낄라                     0.0
# 기타증류주                  87.5
# 기타곡물발효주              2710.1
# Name: (12월, 수출, 중량), dtype: float64

# %%
#2022년 수출 중량
alcohol_export_2022_weight=[]
for i in range(0, 48, 4):
    e=alcohol_trade_2022.T.iloc[i]
    alcohol_export_2022_weight.append(e)
    
alcohol_export_2022_weight=pd.DataFrame(pd.DataFrame(alcohol_export_2022_weight).sum()).T.rename(index={0 : '2022'})
alcohol_export_2022_weight
# Out:
#             맥주  포도주 (원액포함)  포도주 (유사포도주)  기타포도주  과실발효주 (사과술, 배술 등)  \
# 2022  102284.4        36.2          4.8    4.4             2910.9
#
#       청주기타발효주 (와인쿨러 등)    위스키  스카시 위스키  버본 위스키  라이 위스키  ...    진  보드카  \
# 2022              48.2  275.6    225.1     0.8     0.0  ...  0.3  0.0
#
#       기타리큐르 (오가피 등)  브랜디       소주     청주  고량주  데낄라   기타증류주  기타곡물발효주
# 2022        57000.4  0.0  67127.1  362.5  0.0  0.0  1953.5  39477.2
#
# [1 rows x 23 columns]

# %%
#2022년 수출 금액
alcohol_export_2022_price=[]
for i in range(1, 47, 4):
    e=alcohol_trade_2022.T.iloc[i]
    alcohol_export_2022_price.append(e)
    
alcohol_export_2022_price=pd.DataFrame(pd.DataFrame(alcohol_export_2022_price).sum()).T.rename(index={0 : '2022'})
alcohol_export_2022_price
# Out:
#            맥주  포도주 (원액포함)  포도주 (유사포도주)  기타포도주  과실발효주 (사과술, 배술 등)  \
# 2022  69475.0       140.0         25.0   21.0             6990.0
#
#       청주기타발효주 (와인쿨러 등)     위스키  스카시 위스키  버본 위스키  라이 위스키  ...    진  보드카  \
# 2022             353.0  2111.0   1876.0    30.0     0.0  ...  3.0  0.0
#
#       기타리큐르 (오가피 등)  브랜디       소주     청주  고량주  데낄라   기타증류주  기타곡물발효주
# 2022        88946.0  0.0  93356.0  824.0  1.0  0.0  3423.0  24709.0
#
# [1 rows x 23 columns]

# %%
#2022년 수입 중량
alcohol_import_2022_weight=[]
for i in range(2, 47, 4):
    e=alcohol_trade_2022.T.iloc[i]
    alcohol_import_2022_weight.append(e)
    
alcohol_import_2022_weight=pd.DataFrame(pd.DataFrame(alcohol_import_2022_weight).sum()).T.rename(index={0 : '2022'})
alcohol_import_2022_weight
# Out:
#             맥주  포도주 (원액포함)  포도주 (유사포도주)  기타포도주  과실발효주 (사과술, 배술 등)  \
# 2022  228742.9     71020.2       1661.6  288.3            11490.6
#
#       청주기타발효주 (와인쿨러 등)      위스키  스카시 위스키  버본 위스키  라이 위스키  ...      진     보드카  \
# 2022            7935.7  25128.0   8999.0  3756.0    50.3  ...  898.9  2347.3
#
#       기타리큐르 (오가피 등)    브랜디     소주      청주     고량주    데낄라   기타증류주  기타곡물발효주
# 2022         7350.7  155.4  250.5  4840.5  7768.9  866.5  5913.1   5606.7
#
# [1 rows x 23 columns]

# %%
#2022년 수입 금액
alcohol_import_2022_price=[]
for i in range(3, 47, 4):
    e=alcohol_trade_2022.T.iloc[i]
    alcohol_import_2022_price.append(e)
    
alcohol_import_2022_price=pd.DataFrame(pd.DataFrame(alcohol_import_2022_price).sum()).T.rename(index={0 : '2022'})
alcohol_import_2022_price
# Out:
#             맥주  포도주 (원액포함)  포도주 (유사포도주)   기타포도주  과실발효주 (사과술, 배술 등)  \
# 2022  181944.0    534128.0       3712.0  1412.0            11928.0
#
#       청주기타발효주 (와인쿨러 등)       위스키   스카시 위스키   버본 위스키  라이 위스키  ...       진  \
# 2022           13268.0  246755.0  155884.0  18074.0  1003.0  ...  5032.0
#
#          보드카  기타리큐르 (오가피 등)     브랜디      소주       청주      고량주     데낄라   기타증류주  \
# 2022  6955.0        24261.0  1051.0  1109.0  17919.7  16051.0  5472.0  6854.0
#
#       기타곡물발효주
# 2022   4659.0
#
# [1 rows x 23 columns]

# %%
alcohol_import_2019_weight
# Out:
#             맥주  포도주 (원액포함)  포도주 (유사포도주)  기타포도주  과실발효주 (사과술, 배술 등)  \
# 2019  360131.9     43495.3       1487.9  320.4             6580.8
#
#       청주기타발효주 (와인쿨러 등)      위스키     꼬냑       럼      진     보드카  기타리큐르 (오가피 등)  \
# 2019            3432.7  19836.1  126.3  1042.2  497.6  3400.7         5834.9
#
#        브랜디     소주      청주     고량주    데낄라   기타증류주  기타곡물발효주
# 2019  70.3  129.4  4110.6  7464.4  759.4  3683.0   2119.6

# %%
alcohol_import_2020_weight
# Out:
#             맥주  포도주 (원액포함)  포도주 (유사포도주)  기타포도주  과실발효주 (사과술, 배술 등)  \
# 2020  277931.5     54192.9       1587.3  284.1            11427.7
#
#       청주기타발효주 (와인쿨러 등)      위스키     꼬냑      럼      진     보드카  기타리큐르 (오가피 등)  \
# 2020            4914.8  15922.9  136.8  749.0  500.2  2037.1         5002.0
#
#        브랜디     소주      청주     고량주    데낄라   기타증류주  기타곡물발효주
# 2020  70.8  172.5  2378.9  7427.0  434.1  3824.2   4893.3

# %%
alcohol_import_2021_weight
# Out:
#             맥주  포도주 (원액포함)  포도주 (유사포도주)  기타포도주  과실발효주 (사과술, 배술 등)  \
# 2021  257932.1     76575.3       1799.2  303.3            14709.0
#
#       청주기타발효주 (와인쿨러 등)      위스키  스카시 위스키  버본 위스키  라이 위스키  ...      진     보드카  \
# 2021            8664.6  15661.4   5677.0  1167.6    17.3  ...  548.1  2266.4
#
#       기타리큐르 (오가피 등)    브랜디    소주      청주     고량주    데낄라   기타증류주  기타곡물발효주
# 2021         4995.7  101.2  94.8  3108.7  7122.6  454.0  6029.8   6508.2
#
# [1 rows x 23 columns]

# %%
alcohol_import_2022_weight
# Out:
#             맥주  포도주 (원액포함)  포도주 (유사포도주)  기타포도주  과실발효주 (사과술, 배술 등)  \
# 2022  228742.9     71020.2       1661.6  288.3            11490.6
#
#       청주기타발효주 (와인쿨러 등)      위스키  스카시 위스키  버본 위스키  라이 위스키  ...      진     보드카  \
# 2022            7935.7  25128.0   8999.0  3756.0    50.3  ...  898.9  2347.3
#
#       기타리큐르 (오가피 등)    브랜디     소주      청주     고량주    데낄라   기타증류주  기타곡물발효주
# 2022         7350.7  155.4  250.5  4840.5  7768.9  866.5  5913.1   5606.7
#
# [1 rows x 23 columns]

# %%
frame=[alcohol_import_2018_weight, alcohol_import_2019_weight, alcohol_import_2020_weight, alcohol_import_2021_weight, alcohol_import_2022_weight]
alcohol_import_weight_trend=pd.concat(frame).dropna(axis=1)
alcohol_import_weight_trend
# Out:
#             맥주  포도주 (원액포함)  포도주 (유사포도주)   기타포도주  과실발효주 (사과술, 배술 등)  \
# 2000    8342.3      8052.5         79.7  1393.6              201.6
# 2001   19465.3      8861.7         38.9  1156.1              170.0
# 2002   20054.6     11522.4         39.8  1946.5              267.5
# 2003   20709.8     13979.7         28.1  1582.9              422.7
# 2004   21333.7     15897.7         43.3   880.4              359.2
# 2005   22828.5     18984.1         71.6  1097.5              192.5
# 2006   26911.6     22194.4         89.8   746.4              351.2
# 2007   35816.0     31810.2         39.0   803.9              470.8
# 2008   43196.3     28795.3         25.5   667.5              558.3
# 2009   41491.7     23009.4         30.1   280.9              467.1
# 2010   48712.6     24568.1        336.7   395.0              561.4
# 2011   58993.0     26004.0        140.5   416.4              485.5
# 2012   74749.5     28083.8        287.3   349.6              807.3
# ...

# %%
alcohol_import_weight_trend.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 23 entries, 2000 to 2022
# Data columns (total 19 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   맥주                 23 non-null     float64
#  1   포도주 (원액포함)         23 non-null     float64
#  2   포도주 (유사포도주)        23 non-null     float64
#  3   기타포도주              23 non-null     float64
#  4   과실발효주 (사과술, 배술 등)  23 non-null     float64
#  5   청주기타발효주 (와인쿨러 등)   23 non-null     float64
#  6   위스키                23 non-null     float64
#  7   꼬냑                 23 non-null     float64
#  8   럼                  23 non-null     float64
#  9   진                  23 non-null     float64
#  10  보드카                23 non-null     float64
#  11  기타리큐르 (오가피 등)      23 non-null     float64
#  12  브랜디                23 non-null     float64
#  13  소주                 23 non-null     float64
#  14  청주                 23 non-null     float64
# ...

# %%
import plotly.express as px
fig=px.line(alcohol_import_weight_trend, markers=True)
fig.update_layout(title_text='주류별 수입 중량')
fig.update_xaxes(title_text='연도', dtick=1)
fig.update_yaxes(title_text='수입량(kl)')
fig.update_layout(legend_title_text='주류별')
fig.show()
# Out:
# <div>                            <div id="2f3e9043-6009-4b94-912f-1420bdb51bb0" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("2f3e9043-6009-4b94-912f-1420bdb51bb0")) {                    Plotly.newPlot(                        "2f3e9043-6009-4b94-912f-1420bdb51bb0",                        [{"hovertemplate":"variable=\ub9e5\uc8fc<br>index=%{x}<br>value=%{y}<extra></extra>","legendgroup":"\ub9e5\uc8fc","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines+markers","name":"\ub9e5\uc8fc","orientation":"v","showlegend":true,"x":[2000,2001,2002,2003,2004,2005,2006,2007,2008,2009,2010,2011,2012,2013,2014,2015,2016,2017,2018,"2019","2020","2021","2022"],"xaxis":"x","y":[8342.3,19465.3,20054.6,20709.8,21333.7,22828.5,26911.6,3
# ...

# %%
frame=[alcohol_import_2018_price, alcohol_import_2019_price, alcohol_import_2020_price, alcohol_import_2021_price, alcohol_import_2022_price]
alcohol_import_price_trend=pd.concat(frame).dropna(axis=1)
alcohol_import_price_trend.tail(13)
# Out:
#             맥주  포도주 (원액포함)  포도주 (유사포도주)   기타포도주  과실발효주 (사과술, 배술 등)  \
# 2010   43750.0    112888.0        648.0  1866.0              753.0
# 2011   58445.0    132078.0        338.0  2042.0              730.0
# 2012   73591.0    147261.0        628.0  1480.0             1198.0
# 2013   89667.0    171840.0        989.0  1860.0             1998.0
# 2014  111686.0    182179.0       2831.0  1238.0             2373.0
# 2015  141860.0    189805.0       2194.0  1378.0             2459.0
# 2016  181556.0    191445.0       1958.0  1386.0             1449.0
# 2017  263091.0    210038.0       2651.0  1041.0              762.0
# 2018  309683.0    244001.0       2958.0  1194.0             3881.0
# 2019  280881.0    259200.0       3115.0  1342.0             7133.0
# 2020  226409.0    330187.0       3331.0  1135.0            12513.0
# 2021  223099.0    559811.0       4225.0  1518.0            17014.0
# 2022  181944.0    534128.0       3712.0  1412.0            11928.0
#
# ...

# %%
import plotly.express as px
fig=px.line(alcohol_import_price_trend.tail(13), markers=True)
fig.update_layout(title_text='주류별 수입 금액')
fig.update_xaxes(title_text='연도', dtick=1)
fig.update_yaxes(title_text='금액(USD 1,000)')
fig.update_layout(legend_title_text='주류별')
fig.show()
# Out:
# <div>                            <div id="df8d961d-bf5f-4901-85cc-1e9aafcb2542" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("df8d961d-bf5f-4901-85cc-1e9aafcb2542")) {                    Plotly.newPlot(                        "df8d961d-bf5f-4901-85cc-1e9aafcb2542",                        [{"hovertemplate":"variable=\ub9e5\uc8fc<br>index=%{x}<br>value=%{y}<extra></extra>","legendgroup":"\ub9e5\uc8fc","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines+markers","name":"\ub9e5\uc8fc","orientation":"v","showlegend":true,"x":[2010,2011,2012,2013,2014,2015,2016,2017,2018,"2019","2020","2021","2022"],"xaxis":"x","y":[43750.0,58445.0,73591.0,89667.0,111686.0,141860.0,181556.0,263091.0,309683.0,280881.0,226409.0,223099.0,18
# ...

# %%
frame=[alcohol_export_2019_weight, alcohol_export_2020_weight, alcohol_export_2021_weight, alcohol_export_2022_weight]
alcohol_export_weight_trend=pd.concat(frame).dropna(axis=1)
alcohol_export_weight_trend
# Out:
#             맥주  포도주 (원액포함)  포도주 (유사포도주)  기타포도주  과실발효주 (사과술, 배술 등)  \
# 2019  209280.8       175.7          0.0    8.7             1161.4
# 2020  109336.1       147.8          0.0    9.1             1703.2
# 2021   95976.0       144.5          0.0    0.0             2408.5
# 2022  102284.4        36.2          4.8    4.4             2910.9
#
#       청주기타발효주 (와인쿨러 등)     위스키   꼬냑      럼       진     보드카  기타리큐르 (오가피 등)  \
# 2019              83.5  1268.2  0.9  439.5  1181.0  1679.0        18568.7
# 2020              26.0   504.3  0.0    0.1   259.5   933.6        32090.4
# 2021              28.6   181.7  0.0    0.0     3.6     5.4        50588.3
# 2022              48.2   275.6  3.7    0.5     0.3     0.0        57000.4
#
#       브랜디       소주     청주  고량주  데낄라   기타증류주  기타곡물발효주
# 2019  0.1  65812.4  357.4  3.4  0.0  7228.5  54380.2
# 2020  0.1  62185.7  290.6  3.1  0.0  5974.2  54904.3
# 2021  0.0  59529.5  371.4  6.1  0.0  2016.9  41409.9
# ...

# %%
alcohol_export_2018_weight
# Out:
#                맥주       소주      청주      약주       탁주
# level_0
# 2000      34614.5  62889.6  1497.2   148.2    949.5
# 2001      44979.1  76642.1  1106.3   233.0    995.9
# 2002      52862.7  80495.1   718.8   602.0   1526.5
# 2003      55550.0  84655.8   965.8   987.0   1820.1
# 2004      56791.1  95681.8   975.9   781.8   2245.4
# 2005      66196.9  84625.2   932.9  1345.0   3027.9
# 2006      69609.9  90624.5   523.8  1547.5   3763.7
# 2007      60388.9  87663.6   461.4  1161.1   4311.8
# 2008      74466.6  88835.5   589.7  1186.3   5457.2
# 2009      73182.0  81170.7   559.0   743.6   7405.4
# 2010      81315.4  79788.3   610.6   639.3  19414.6
# 2011     104218.1  69367.0   511.7   608.6  43082.0
# 2012     104920.4  77665.2   625.9   666.6  30658.2
# 2013     113155.3  77615.0   675.3   527.1  18221.9
# 2014     111003.8  74338.5   679.7   497.0  15470.0
# 2015     123963.7  72136.5   691.3   396.9  13892.8
# 2016     131484.6  69798.6   449.5   283.1  13654.4
# ...

# %%
frame=[alcohol_export_2018_weight, alcohol_export_2019_weight, alcohol_export_2020_weight, alcohol_export_2021_weight, alcohol_export_2022_weight]
alcohol_export_weight_trend=pd.concat(frame).dropna(axis=1)
alcohol_export_weight_trend=alcohol_export_weight_trend.tail(13)
alcohol_export_weight_trend
# Out:
#             맥주       소주     청주
# 2010   81315.4  79788.3  610.6
# 2011  104218.1  69367.0  511.7
# 2012  104920.4  77665.2  625.9
# 2013  113155.3  77615.0  675.3
# 2014  111003.8  74338.5  679.7
# 2015  123963.7  72136.5  691.3
# 2016  131484.6  69798.6  449.5
# 2017  158198.6  71063.9  355.5
# 2018  211688.3  72181.0  384.2
# 2019  209280.8  65812.4  357.4
# 2020  109336.1  62185.7  290.6
# 2021   95976.0  59529.5  371.4
# 2022  102284.4  67127.1  362.5

# %%
import plotly.express as px
fig=px.line(alcohol_export_weight_trend, markers=True)
#fig.update_layout(title_text='주류별 수출 중량')
fig.update_xaxes(title_text='연도', dtick=1)
fig.update_yaxes(title_text='수출량(kl)')
fig.update_layout(legend_title_text='주류별')

fig.add_annotation(x=2022, y=102284,
            text="맥주",
            showarrow=False,
            font_size=15,
            xanchor = 'left')

fig.show()
# Out:
# <div>                            <div id="a978d0b1-45d7-4e75-8279-1ca7ae5d9d49" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("a978d0b1-45d7-4e75-8279-1ca7ae5d9d49")) {                    Plotly.newPlot(                        "a978d0b1-45d7-4e75-8279-1ca7ae5d9d49",                        [{"hovertemplate":"variable=\ub9e5\uc8fc<br>index=%{x}<br>value=%{y}<extra></extra>","legendgroup":"\ub9e5\uc8fc","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines+markers","name":"\ub9e5\uc8fc","orientation":"v","showlegend":true,"x":[2010,2011,2012,2013,2014,2015,2016,2017,2018,"2019","2020","2021","2022"],"xaxis":"x","y":[81315.4,104218.1,104920.4,113155.3,111003.8,123963.7,131484.6,158198.6,211688.3,209280.8,109336.1,95976.0,
# ...

# %%
beer_export=pd.read_excel('./project_data/beer.xlsx', index_col=0)
beer_export
# Out:
#     품목명     2013년 2013년.1   2013년.2 2013년.3    2013년.4     2014년 2014년 (12월)  \
# 국가
# 순번  품목명      수출중량   수출증감률      수입중량   수입증감률         수지      수출중량       수출증감률
# CN   맥주  13652949    36.4   8782689      23    4870259  20111718        47.3
# HK   맥주  56979964    11.1    513987   445.8   56465976  55483790        -2.6
# JP   맥주   4632278   -38.6  25047092    30.9  -20414814   3867394       -16.5
# MN   맥주   8288160     -17        20   -98.9    8288139   3973888       -52.1
# SG   맥주  12164394    20.6    163814    28.9   12000580   5288071       -56.5
# VN   맥주     14928       0    955587    48.4    -940659     64580       332.6
# TW   맥주   3135258     7.8      3382   -78.7    3131875   3680688        17.4
#
#    2014년 (12월).1 2014년 (12월).2  ...     2017년 2017년 (12월) 2017년 (12월).1  \
# 국가                              ...
# 순번          수입중량         수입증감률  ...      수출중량       수출증감률          수입중량
# CN      11490381          30.8  ...  65031832       105.7      50961429
# ...

# %%
beer_export=beer_export.drop(['순번'])
beer_export
# Out:
#    품목명     2013년 2013년.1   2013년.2 2013년.3    2013년.4     2014년 2014년 (12월)  \
# 국가
# CN  맥주  13652949    36.4   8782689      23    4870259  20111718        47.3
# HK  맥주  56979964    11.1    513987   445.8   56465976  55483790        -2.6
# JP  맥주   4632278   -38.6  25047092    30.9  -20414814   3867394       -16.5
# MN  맥주   8288160     -17        20   -98.9    8288139   3973888       -52.1
# SG  맥주  12164394    20.6    163814    28.9   12000580   5288071       -56.5
# VN  맥주     14928       0    955587    48.4    -940659     64580       332.6
# TW  맥주   3135258     7.8      3382   -78.7    3131875   3680688        17.4
#
#    2014년 (12월).1 2014년 (12월).2  ...     2017년 2017년 (12월) 2017년 (12월).1  \
# 국가                              ...
# CN      11490381          30.8  ...  65031832       105.7      50961429
# HK        865126          68.3  ...  55884342        -0.7       3998003
# JP      31914035          27.4  ...   3613011       -35.7      79988079
# ...

# %%
beer_export=beer_export[['2013년', '2014년', '2015년', '2016년', '2017년', '2018년']]
beer_export
# Out:
#        2013년     2014년     2015년     2016년     2017년      2018년
# 국가
# CN  13652949  20111718  25707134  31616683  65031832  105588540
# HK  56979964  55483790  57395057  56287903  55884342   58219420
# JP   4632278   3867394   2710461   5620333   3613011    3097529
# MN   8288160   3973888   2634613   2114084   1194774    2052638
# SG  12164394   5288071   9354411   7171774   5912130    6562985
# VN     14928     64580    464095    367175    592280     404854
# TW   3135258   3680688   3582083   3417116   3029117    2866784

# %%
beer_export.T
# Out:
# 국가            CN        HK       JP       MN        SG      VN       TW
# 2013년   13652949  56979964  4632278  8288160  12164394   14928  3135258
# 2014년   20111718  55483790  3867394  3973888   5288071   64580  3680688
# 2015년   25707134  57395057  2710461  2634613   9354411  464095  3582083
# 2016년   31616683  56287903  5620333  2114084   7171774  367175  3417116
# 2017년   65031832  55884342  3613011  1194774   5912130  592280  3029117
# 2018년  105588540  58219420  3097529  2052638   6562985  404854  2866784

# %%
beer_export['2013년']
# Out:
# 국가
# CN    13652949
# HK    56979964
# JP     4632278
# MN     8288160
# SG    12164394
# VN       14928
# TW     3135258
# Name: 2013년, dtype: object

# %%
import plotly.express as px
fig=px.line(beer_export.T, markers=True)
#fig.update_layout(title_text='주류 총 출고량')
fig.update_xaxes(dtick=1)
fig.update_yaxes(title_text='수출량(kl)')
fig_i.update_layout(legend_title_text='국가')

# fig.add_annotation(x=2018, y=1,
#             text="중국",
#             showarrow=False,
#             font_size=15,
#             xanchor = 'left')
# fig.add_annotation(x=2018, y=102284,
#             text="맥주",
#             showarrow=False,
#             font_size=15,
#             xanchor = 'left')

fig.show()
# Out:
# <div>                            <div id="54d1f144-7460-485c-9455-f884a58b6aec" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("54d1f144-7460-485c-9455-f884a58b6aec")) {                    Plotly.newPlot(                        "54d1f144-7460-485c-9455-f884a58b6aec",                        [{"hovertemplate":"\uad6d\uac00=CN<br>index=%{x}<br>value=%{y}<extra></extra>","legendgroup":"CN","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines+markers","name":"CN","orientation":"v","showlegend":true,"x":["2013\ub144","2014\ub144","2015\ub144","2016\ub144","2017\ub144","2018\ub144"],"xaxis":"x","y":[13652949,20111718,25707134,31616683,65031832,105588540],"yaxis":"y","type":"scatter"},{"hovertemplate":"\uad6d\uac00=HK<br>inde
# ...

# %%
import plotly.express as px
fig=px.line(beer_export.T, markers=True)
#fig.update_layout(title_text='주류 총 출고량')
fig.update_xaxes(title_text='연도', dtick=1)
fig.update_yaxes(title_text='수출량(kl)')
fig_i.update_layout(legend_title_text='국가')

fig.add_annotation(x='2018년', y=105588500,
            text="중국",
            showarrow=False,
            font_size=15,
            xanchor = 'left')
fig.add_annotation(x='2018년', y=58219420,
            text="홍콩",
            showarrow=False,
            font_size=15,
            xanchor = 'left')

fig.show()
# Out:
# <div>                            <div id="9e6f43fe-956d-4435-930e-8e755303afea" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("9e6f43fe-956d-4435-930e-8e755303afea")) {                    Plotly.newPlot(                        "9e6f43fe-956d-4435-930e-8e755303afea",                        [{"hovertemplate":"\uad6d\uac00=CN<br>index=%{x}<br>value=%{y}<extra></extra>","legendgroup":"CN","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines+markers","name":"CN","orientation":"v","showlegend":true,"x":["2013\ub144","2014\ub144","2015\ub144","2016\ub144","2017\ub144","2018\ub144"],"xaxis":"x","y":[13652949,20111718,25707134,31616683,65031832,105588540],"yaxis":"y","type":"scatter"},{"hovertemplate":"\uad6d\uac00=HK<br>inde
# ...

# %%
alcohol_tax=pd.read_excel('./project_data/alcohol_tax.xls', index_col=0)

# %%
alcohol_tax=alcohol_tax.drop(['구분', '합계'], axis=1)
alcohol_tax=alcohol_tax.tail(11)
alcohol_tax
# Out:
#          탁주     약주     청주       맥주     과실주  증류식 소주   희석식 소주     위스키   브랜디  \
# 연도
# 2010  19448  21175  26001  1289116   71147    3527   968083  264510  8501
# 2011  21971  21908  27460  1346794   73523    3281   968300  234546  7112
# 2012  21444  18464  27486  1430242   72473    3387  1011468  204417  5309
# 2013  20345  17119  29600  1544699   81381    4015  1052401  171016  5640
# 2014  20580  14667  29404  1568691   83207    4857  1138898  172174  4702
# 2015  20204  13557  28051  1608517   87680    6573  1171309  167310  4939
# 2016  19504  13475  29432  1602639   96572    8402  1212082  149588  5771
# 2017  19172  11984  28906  1635590   93890   11185  1243197  127508  5089
# 2018  19713  12625  31108  1581410  101532   11354  1223024  124176  5150
# 2019  19003  12209  28358  1504237  112796   12937  1263613  123103  5295
# 2020  18760  10461  26278  1336363  141300   14943  1251997  112023  5575
#
#       일반 증류주    리큐르  기타 주류    주정
# 연도
# 2010   14647  10566   2737  2619
# ...

# %%
import plotly.express as px

fig=px.line(alcohol_tax, markers=True)
fig.update_layout(title_text='주류 세액')
fig.update_xaxes(dtick=1)
fig.update_yaxes(title_text='세액')
fig.update_layout(legend_title_text='주류별')

fig.show()
# Out:
# <div>                            <div id="4e2e2ac9-0afd-41d8-bf62-27697464c737" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("4e2e2ac9-0afd-41d8-bf62-27697464c737")) {                    Plotly.newPlot(                        "4e2e2ac9-0afd-41d8-bf62-27697464c737",                        [{"hovertemplate":"variable=\ud0c1\uc8fc<br>\uc5f0\ub3c4=%{x}<br>value=%{y}<extra></extra>","legendgroup":"\ud0c1\uc8fc","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines+markers","name":"\ud0c1\uc8fc","orientation":"v","showlegend":true,"x":[2010,2011,2012,2013,2014,2015,2016,2017,2018,2019,2020],"xaxis":"x","y":[19448,21971,21444,20345,20580,20204,19504,19172,19713,19003,18760],"yaxis":"y","type":"scatter"},{"hovertemplate":"va
# ...
